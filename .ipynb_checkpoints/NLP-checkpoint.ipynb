# %%
#load json data. 
#https://stackoverflow.com/questions/21058935/python-json-loads-shows-valueerror-extra-data

import json    

data = []
with open('Ex-drug.json',encoding="utf8") as f:
    for line in f:
        data.append(json.loads(line))

# %%
#load json into a dataframe
import pandas as pd
#https://stackoverflow.com/questions/41168558/python-how-to-convert-json-file-to-dataframe

df = pd.DataFrame.from_dict(data, orient='columns')

# %%
df
# Out:
#                   author                                                cid  \
# 0           Jessica Anne                         UgzSsKbt4sFSenKFwed4AaABAg
# 1                 eric t                         UgyUSy_h7yM8zWjBqYh4AaABAg
# 2                 Zach R                         Ugx5UKyJHBdvXmdIxK14AaABAg
# 3            Lev Myshkin                         UgztLzG86StfFJi_qLZ4AaABAg
# 4                 E DubZ                         UgyH7-hMSf6nedCO-S54AaABAg
# 5            Ben Sorrell                         UgwlgpVvzxYoQm6gpsZ4AaABAg
# 6          Eric Mitchell                         Ugy9MzW_M4LAV2d4Dvl4AaABAg
# 7              J Wallace                         Ugy9thu5rvpgYO3d9994AaABAg
# 8               Dan Matz                         UgxHXnKx1X_vGqYu1_14AaABAg
# 9    Octavio Vega-Orozco                         UgxCDBnlGnZr8pRBaSF4AaABAg
# 10    Ukrainianification                         UgyQauJuvXYzkhhvA5N4AaABAg
# 11               Slick S                         UgwojDu8RpLRfPJBaPR4AaABAg
# 12                  Beau                         UgzBpTCgzPIpZtAel_h4AaABAg
# 13          Erik Charlat                         UgzBz338vbyDbSe6e7x4AaABAg
# 14        peadey mclovin                         Ugxug9qGyGUcTDg6et14AaABAg
# 15       christian yates                         UgxrNpl0yZGxlihqmgd4AaABAg
# 16                No One                         UgyOa826C8QIUR0pBlh4AaABAg
# 17            first last                         UgyO6eWTDayAvmnnmph4AaABAg
# 18            first last  UgyO6eWTDayAvmnnmph4AaABAg.8liF8HuE9si8liFCurobgZ
# 19          Andrew Logan                         UgxpCz_NpeH_B9v8_1B4AaABAg
# 20           Drmoonlordx                         UgzGChcFBM2JiWysxbJ4AaABAg
# 21        Carlos Trevizo                         Ugyn_whedpFoYqjGb4t4AaABAg
# 22                 cirie                         UgxwXF1iHVeu_gRtcQh4AaABAg
# 23         David Watkins                         Ugxq80IqMQaJM2GMSB94AaABAg
# 24            Tango Nice                         UgxSdHbfV6hxOCy1tah4AaABAg
# 25     The Nameless King                         UgxbHpp9iN27ttami5J4AaABAg
# 26                   cvc                         UgzYMeUJ0ITag-qw87p4AaABAg
# 27     Laurence Anderson                         Ugw_jqVm_rF0P99U3EN4AaABAg
# 28         freeagenttidy  Ugw_jqVm_rF0P99U3EN4AaABAg.8lhI2gNmGLz8lhloavHhcX
# 29           joshua hand                         UgzLJ2hyMy_vjaE2y6F4AaABAg
# ..                   ...                                                ...
# 825            wikichris  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYJH3_8jX2
# 826     Rapgame Tomhanks  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYJaM0N7v8
# 827              weehawk  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYKYueKJn8
# 828      NoTimeToExplain  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYL6v1E_a4
# 829        Harry Ballzac  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYLwgE6hrb
# 830      ExpressYourself  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYP4s9hZZy
# 831  Sovereign Sentience  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYPpXJ_KWC
# 832            Gexslayer  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYQKEVcJMJ
# 833      Sizwe. A Mabaso  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYT699SXSY
# 834    Delamthedestroyer  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYbkTt_yRz
# 835                pihyv  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYe1UTtJTW
# 836       Charlie Walter  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYkCZUOWMl
# 837                 Plop  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lYsVZIP7L4
# 838             Brian D.  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lZFmJzhLsm
# 839      Backon Thelevel  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8lZfk0AbRHR
# 840             EZ Duzit  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8la8kyEtDuq
# 841        Philip Doenau  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8llfsYTzg_F
# 842          Lev Myshkin  UgxGruKA0J4P1K6s2wN4AaABAg.8lYHYjuectC8llsY3WioH5
# 843           M Allsorts                         Ugw_fqiaTrffF-yOKvV4AaABAg
# 844          Hip hop Era  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lYXDX3SUlB
# 845       ghostfrequency  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lYYWpIpu8Z
# 846           B. Tisdale  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lYcAbftX4j
# 847        Joanne porter  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lYz6wkWdl2
# 848            Ace Entry  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lZ3oTcKa3R
# 849       Kaleb Breckord  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lZTzzAkpxI
# 850      zahier_ gaidien  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lZpTPdscZB
# 851        thenoodleshop  Ugw_fqiaTrffF-yOKvV4AaABAg.8lYHXytlLbr8lZtXhaGK9j
# 852         Kenny Martin                         UgxJvm4bXiw5BWMfEad4AaABAg
# 853            Queen Nef                         Ugwdlxq6TxlmDFuOf8R4AaABAg
# 854           Lazarus VO                         Ugz-g-H9LynTp_FoCxJ4AaABAg
#
#                                                   text                 time
# 0    This really seems like a guy who deserves an h...       32 minutes ago
# 1    Wow a cop that gets it! It'll never happen tho...         13 hours ago
# 2    The war on drugs is a war on people who consum...         13 hours ago
# 3    A war on drugs sounds amazing, thousands of so...         18 hours ago
# 4    The govt realizes how futile the drug war in r...         19 hours ago
# 5    socialism from the same country that allows mu...         22 hours ago
# 6    Excellent, I love VICE ... let’s legalise ever...         23 hours ago
# 7    All drugs should be decrimimalized, I dont thi...   1 day ago (edited)
# 8    I think they need to change Vice to everybody ...            1 day ago
# 9    what does "they were just taking a mickey" mean?﻿            1 day ago
# 10   I love all the internet moralists and haters o...            1 day ago
# 11   "I just made the lives of the vulnerable more ...            1 day ago
# 12                                   Fucking scumbag.﻿            1 day ago
# 13   just another pig ruining peoples lives for not...            1 day ago
# 14   10 Questions You Always Wanted to Ask... "Hey ...            1 day ago
# 15                     "A stone of crack".\n British.﻿           2 days ago
# 16   He is a smart boi. Many people can’t accept wh...           2 days ago
# 17   So imagine meth was legal and regulated would,...           2 days ago
# 18   Cannabis too, how can it be one of the only dr...           2 days ago
# 19   its always been mainly about the money not to ...           2 days ago
# 20   Research Portugals drug policy its mind blowin...           2 days ago
# 21                      I like this guy he seems cool﻿           2 days ago
# 22   this shits so true he acknowledges that the en...           2 days ago
# 23   I dress smart & to look at me you'd not likely...           2 days ago
# 24            🤢🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮﻿           2 days ago
# 25                       This sounds like a cool game﻿           2 days ago
# 26   What a truly piece of shit.  Manipulating the ...  2 days ago (edited)
# 27   ive seen this ages ago!!!!! why re re-release ...           2 days ago
# 28   It's just a big massive dream that keeps on re...           2 days ago
# 29    Republicans, like me, need to end the drug war.﻿           2 days ago
# ..                                                 ...                  ...
# 825           Why not just fart? Makes no sense. Gay.﻿           6 days ago
# 826  Opposite for me. I push them together so that ...           6 days ago
# 827  This seems better than doing it not in the sho...           6 days ago
# 828  This comment was highlighted, everyone knows y...           6 days ago
# 829  I do it while taking a bath, the bubbles are s...           6 days ago
# 830  and feeling the water running and caressing th...  6 days ago (edited)
# 831  Mike if you move your buttcheeks back and fort...           6 days ago
# 832                                I feel you brother﻿           6 days ago
# 833            I need counseling after imagining that﻿           6 days ago
# 834  I do that too because it makes a sound like an...           6 days ago
# 835                                            Oh yes﻿           6 days ago
# 836                                        😂😂😂😂😂😂😂😂😂😂﻿           6 days ago
# 837            Anyone else squat on their toilet seat﻿           6 days ago
# 838                                          Hahaha🤣🤣﻿           6 days ago
# 839  @Plop I prefer to sit on my toilet backwards, ...           5 days ago
# 840                  And how does that make you feel?﻿           5 days ago
# 841  Why bother commenting this shit at all? You cl...         20 hours ago
# 842  Philip Doenau I think they find it funny becau...         18 hours ago
# 843  "My colleague disguised himself as a bag of co...           6 days ago
# 844                        M Allsorts u funny barstad﻿           6 days ago
# 845                      priceless bro ha ha ha damn.﻿           6 days ago
# 846  You... you are what I've been missing my entir...           6 days ago
# 847                                         Good that﻿           6 days ago
# 848                       Do you write for the Boosh?﻿           6 days ago
# 849                                   I peed a little﻿           5 days ago
# 850                                       Hahaha lol.﻿           5 days ago
# 851                                Is this brass eye?﻿           5 days ago
# 852                                             Third﻿           6 days ago
# 853                             Enjoyed this videoooo﻿           6 days ago
# 854                      That's amazing great work ^^﻿           6 days ago
#
# [855 rows x 4 columns]

# %%
# for ele in data:
#     print(ele['text'])

# %%
df["text"]
# Out:
# 0      This really seems like a guy who deserves an h...
# 1      Wow a cop that gets it! It'll never happen tho...
# 2      The war on drugs is a war on people who consum...
# 3      A war on drugs sounds amazing, thousands of so...
# 4      The govt realizes how futile the drug war in r...
# 5      socialism from the same country that allows mu...
# 6      Excellent, I love VICE ... let’s legalise ever...
# 7      All drugs should be decrimimalized, I dont thi...
# 8      I think they need to change Vice to everybody ...
# 9      what does "they were just taking a mickey" mean?﻿
# 10     I love all the internet moralists and haters o...
# 11     "I just made the lives of the vulnerable more ...
# 12                                     Fucking scumbag.﻿
# 13     just another pig ruining peoples lives for not...
# 14     10 Questions You Always Wanted to Ask... "Hey ...
# 15                       "A stone of crack".\n British.﻿
# 16     He is a smart boi. Many people can’t accept wh...
# 17     So imagine meth was legal and regulated would,...
# 18     Cannabis too, how can it be one of the only dr...
# 19     its always been mainly about the money not to ...
# 20     Research Portugals drug policy its mind blowin...
# 21                        I like this guy he seems cool﻿
# 22     this shits so true he acknowledges that the en...
# 23     I dress smart & to look at me you'd not likely...
# 24              🤢🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮﻿
# 25                         This sounds like a cool game﻿
# 26     What a truly piece of shit.  Manipulating the ...
# 27     ive seen this ages ago!!!!! why re re-release ...
# 28     It's just a big massive dream that keeps on re...
# 29      Republicans, like me, need to end the drug war.﻿
#                              ...
# 825             Why not just fart? Makes no sense. Gay.﻿
# 826    Opposite for me. I push them together so that ...
# 827    This seems better than doing it not in the sho...
# 828    This comment was highlighted, everyone knows y...
# 829    I do it while taking a bath, the bubbles are s...
# 830    and feeling the water running and caressing th...
# 831    Mike if you move your buttcheeks back and fort...
# 832                                  I feel you brother﻿
# 833              I need counseling after imagining that﻿
# 834    I do that too because it makes a sound like an...
# 835                                              Oh yes﻿
# 836                                          😂😂😂😂😂😂😂😂😂😂﻿
# 837              Anyone else squat on their toilet seat﻿
# 838                                            Hahaha🤣🤣﻿
# 839    @Plop I prefer to sit on my toilet backwards, ...
# 840                    And how does that make you feel?﻿
# 841    Why bother commenting this shit at all? You cl...
# 842    Philip Doenau I think they find it funny becau...
# 843    "My colleague disguised himself as a bag of co...
# 844                          M Allsorts u funny barstad﻿
# 845                        priceless bro ha ha ha damn.﻿
# 846    You... you are what I've been missing my entir...
# 847                                           Good that﻿
# 848                         Do you write for the Boosh?﻿
# 849                                     I peed a little﻿
# 850                                         Hahaha lol.﻿
# 851                                  Is this brass eye?﻿
# 852                                               Third﻿
# 853                               Enjoyed this videoooo﻿
# 854                        That's amazing great work ^^﻿
# Name: text, Length: 855, dtype: object

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *


stemmer = PorterStemmer()

lemtzer = WordNetLemmatizer()

def lemmatize_stemming(text):
    return lemtzer.lemmatize(text, pos='n')
    return stemmer.stem(text)

# Write a function to perform the pre processing steps on the entire dataset
def preprocess(text):
    result=[]
    for token in simple_preprocess(text) :
        if token not in STOPWORDS:
            result.append(lemmatize_stemming(token))
            
    return result

processed_docs  = []

for doc in df["text"]:
    processed_docs.append(preprocess(doc))

#processed_docs

import gensim
dictionary = gensim.corpora.Dictionary(processed_docs)

        

bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[300]

processed_docs
# Out:
# C:\Users\samuelmao\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [['like',
#   'guy',
#   'deserves',
#   'hour',
#   'tell',
#   'story',
#   'point',
#   'saw',
#   'video',
#   'thought',
#   'shit'],
#  ['wow',
#   'cop',
#   'get',
#   'll',
#   'happen',
#   'prison',
#   'complex',
#   'dea',
#   'judge',
#   'lawyer',
#   'cop',
#   'money',
#   'legalize',
#   'drug',
#   'list',
#   'statistic',
#   'day',
#   'dea',
#   'website',
#   'waste',
#   'silly',
#   'unwinnable',
#   'war',
#   'drug',
#   'land',
#   'free',
#   'million',
#   'folk',
#   'prison',
#   'drug',
#   'important',
#   'right',
#   'tell',
#   'body',
#   'especially',
#   'politician',
#   'doctor',
#   'asinine',
#   'policy'],
#  ['war',
#   'drug',
#   'war',
#   'people',
#   'consume',
#   'drug',
#   'patented',
#   'drug',
#   'low',
#   'amount',
#   'cbd',
#   'ethanol',
#   'filler',
#   'sugar',
#   'moved',
#   'schedule',
#   'hilarious',
#   'didnt',
#   'physically',
#   'ill',
#   'money',
#   'power',
#   'helping',
#   'racism',
#   'thrown'],
#  ['war',
#   'drug',
#   'sound',
#   'amazing',
#   'thousand',
#   'soldier',
#   'acid',
#   'throwing',
#   'grenade',
#   'crashing',
#   'chinook'],
#  ['govt',
#   'realizes',
#   'futile',
#   'drug',
#   'war',
#   'regard',
#   'getting',
#   'drug',
#   'street',
#   'way',
#   'control',
#   'ethnic',
#   'group',
#   'dumbing',
#   'population',
#   'oppose',
#   'power',
#   'ruining',
#   'financially',
#   'an',
#   'destroy',
#   'motivation',
#   'priority',
#   'constructive',
#   'people',
#   'broke',
#   'preoccupied',
#   'living',
#   'im',
#   'constant',
#   'fear',
#   'make',
#   'easy',
#   'control'],
#  ['socialism',
#   'country',
#   'allows',
#   'muslim',
#   'bomb',
#   'rape',
#   'pillage',
#   'great',
#   'nation',
#   'vice',
#   'shit',
#   'liberal',
#   'podium'],
#  ['excellent',
#   'love',
#   'vice',
#   'let',
#   'legalise',
#   'drug',
#   'sending',
#   'drug',
#   'dealer',
#   'user',
#   'rehab'],
#  ['drug',
#   'decrimimalized',
#   'dont',
#   'think',
#   'legal',
#   'drug',
#   'addict',
#   'prison',
#   'non',
#   'violent',
#   'drug',
#   'addict',
#   'need',
#   'help'],
#  ['think', 'need', 'change', 'vice', 'everybody', 'racist', 'channel'],
#  ['taking', 'mickey', 'mean'],
#  ['love',
#   'internet',
#   'moralist',
#   'hater',
#   'generalizing',
#   'perceived',
#   'stereotype',
#   'fed',
#   'medium',
#   'instead',
#   'fueled',
#   'hate',
#   'focus',
#   'providing',
#   'useful',
#   'option',
#   'dealing',
#   'situation',
#   'improving',
#   'society',
#   'general',
#   'easy',
#   'answer',
#   'people',
#   'blindly',
#   'hate',
#   'furthering',
#   'social',
#   'demise',
#   'man',
#   'shared',
#   'life',
#   'story',
#   'learned',
#   'maybe',
#   'learn',
#   'choose',
#   'revert',
#   'calling',
#   'typing',
#   'cowardly',
#   'hate',
#   'message',
#   'mom',
#   'basement',
#   'spreading',
#   'hate',
#   'maybe',
#   'playing',
#   'video',
#   'game'],
#  ['life',
#   'vulnerable',
#   'unbearable',
#   'likely',
#   'time',
#   'hear',
#   'police',
#   'officer',
#   'recognize'],
#  ['fucking', 'scumbag'],
#  ['pig',
#   'ruining',
#   'people',
#   'life',
#   'collect',
#   'tax',
#   'dollar',
#   'paycheck',
#   'celebrate',
#   'death'],
#  ['question', 'wanted', 'ask', 'hey', 'bro', 'cop'],
#  ['stone', 'crack', 'british'],
#  ['smart',
#   'boi',
#   'people',
#   'accept',
#   'man',
#   'said',
#   'regulation',
#   'key',
#   'crime',
#   'reduction',
#   'harm',
#   'reduction'],
#  ['imagine',
#   'meth',
#   'legal',
#   'regulated',
#   'vice',
#   'want',
#   'people',
#   'taking',
#   'shit',
#   'drug',
#   'mug'],
#  ['cannabis', 'drug', 'week'],
#  ['mainly',
#   'money',
#   'racism',
#   'wasn',
#   'factor',
#   'plenty',
#   'white',
#   'people',
#   'life',
#   'sentence',
#   'drug',
#   'offense'],
#  ['research', 'portugal', 'drug', 'policy', 'mind', 'blowing', 'haha'],
#  ['like', 'guy', 'cool'],
#  ['shit',
#   'true',
#   'acknowledges',
#   'entire',
#   'built',
#   'prey',
#   'weak',
#   'vulnerable'],
#  ['dress',
#   'smart',
#   'look',
#   'likely',
#   'think',
#   'use',
#   'drug',
#   'worked',
#   'time',
#   'scoring',
#   'dealer',
#   'cagey',
#   'serving'],
#  [],
#  ['sound', 'like', 'cool', 'game'],
#  ['truly',
#   'piece',
#   'shit',
#   'manipulating',
#   'desperate',
#   'ruining',
#   'life',
#   'build',
#   'case',
#   'guy',
#   'year',
#   'charge',
#   'stick',
#   'undercover',
#   'work',
#   'need',
#   'reform',
#   'imo',
#   'mean',
#   'respect',
#   'trying',
#   'bust',
#   'people',
#   'vulnerables',
#   'rarely',
#   'el',
#   'chapo',
#   'guy',
#   'got',
#   'respect',
#   'slimeball',
#   'come',
#   'term',
#   'slimeball',
#   'piece',
#   'shit'],
#  ['ive', 'seen', 'age', 'ago', 'release', 'video'],
#  ['big', 'massive', 'dream', 'keep', 'repeating'],
#  ['republican', 'like', 'need', 'end', 'drug', 'war'],
#  ['end'],
#  ['meth',
#   'manufactured',
#   'sold',
#   'exclusively',
#   'white',
#   'dealt',
#   'accordingly',
#   'exclusively',
#   'white',
#   'cop',
#   'lawmaker',
#   'heavy',
#   'penalty',
#   'control',
#   'ephedrine',
#   'stop',
#   'blaming',
#   'whitey'],
#  ['agree', 'guy', 'criminalizing', 'people', 'worked'],
#  ['racism', 'lol'],
#  ['want',
#   'better',
#   'insight',
#   'man',
#   'life',
#   'watch',
#   'podcast',
#   'true',
#   'geordie',
#   'podcast'],
#  ['racist',
#   'citation',
#   'needed',
#   'vice',
#   'tho',
#   'racist',
#   'sexist',
#   'xenophobic'],
#  ['opinion',
#   'legalize',
#   'equal',
#   'enforcement',
#   'user',
#   'dealer',
#   'people',
#   'product',
#   'having',
#   'jail',
#   'time',
#   'guess',
#   'happens',
#   'drug',
#   'problem',
#   'got',
#   'philippine'],
#  ['vice',
#   'cancerous',
#   'fucking',
#   'mole',
#   'news',
#   'landscape',
#   'remember',
#   'vice',
#   'honest',
#   'groundbreaking',
#   'weak',
#   'as',
#   'son',
#   'took'],
#  ['isn',
#   'true',
#   'making',
#   'joke',
#   'drug',
#   'trade',
#   'run',
#   'people',
#   'enforced',
#   'stop',
#   'simple',
#   'easy',
#   'corrupt',
#   'people',
#   'follow',
#   'money'],
#  ['nark'],
#  ['book', 'best', 'book', 'read', 'good', 'cop', 'bad', 'war'],
#  ['recommend'],
#  ['wanna', 'watch', 'deep'],
#  ['yo', 'vice'],
#  ['great', 'work'],
#  ['wire'],
#  ['change', 'title', 'narc'],
#  ['legend',
#   'ball',
#   'pull',
#   'undercover',
#   'policing',
#   'come',
#   'intelligent',
#   'good',
#   'segment'],
#  ['make', 'laugh', 'live', 'derby', 'interesting', 'stuff'],
#  ['oh',
#   'fuck',
#   'yank',
#   'race',
#   'fact',
#   'minority',
#   'started',
#   'taking',
#   'drug',
#   'en',
#   'mass',
#   'white',
#   'people',
#   'typically',
#   'dont',
#   'drug',
#   'eventually',
#   'stop'],
#  [],
#  ['day', 'comment', 'll', 'successful', 'drug', 'lord'],
#  ['lying'],
#  ['guy',
#   'rid',
#   'heroin',
#   'epidemic',
#   'available',
#   'medical',
#   'use',
#   'll',
#   'away',
#   'illegal',
#   'distribution',
#   'abuse',
#   'isn',
#   'heroin',
#   'medically',
#   'altered',
#   'countless',
#   'case',
#   'patient',
#   'struggling',
#   'opiate',
#   'addiction',
#   'heroin',
#   'like',
#   'marijuana',
#   'lmao',
#   'gonna',
#   'big',
#   'business',
#   'big',
#   'pharma',
#   'oh',
#   'yeah',
#   'cop',
#   'wouldn',
#   'surprised',
#   'control',
#   'establishment',
#   'money',
#   'interest',
#   'good',
#   'video'],
#  ['yup',
#   'time',
#   'feel',
#   'like',
#   'cop',
#   'like',
#   'tail',
#   'light',
#   'pull',
#   'try',
#   'use',
#   'mind',
#   'game',
#   'try',
#   've',
#   'got',
#   'reason',
#   'suspect',
#   'criminal',
#   'definitely',
#   'make',
#   'feel',
#   'like',
#   'contrast'],
#  ['cop', 'brain', 'know', 'truth', 'drug', 'war'],
#  ['ex', 'cop', 'ex', 'plain'],
#  ['vice',
#   'channel',
#   'shit',
#   'zero',
#   'content',
#   'youtube',
#   'second',
#   'thing',
#   've',
#   'watch',
#   'week',
#   'online',
#   've',
#   'enjoyed'],
#  ['piece', 'shit'],
#  ['real'],
#  ['racist', 'bet', 'scary', 'stuff'],
#  ['knew',
#   'lad',
#   'sold',
#   'mkat',
#   'illegal',
#   'literally',
#   'order',
#   'net',
#   'drop',
#   'letterbox',
#   'illegal',
#   'asked',
#   'gonna',
#   'said',
#   'going',
#   'price'],
#  ['like',
#   'song',
#   'said',
#   'research',
#   'successful',
#   'drug',
#   'policy',
#   'show',
#   'treatment',
#   'increased',
#   'law',
#   'enforcement',
#   'decreased',
#   'abolishing',
#   'mandatory',
#   'minimum',
#   'sentencing',
#   'state',
#   'legalize',
#   'weed',
#   'life',
#   'better',
#   'ton',
#   'people'],
#  ['child', 'somebody', 'think', 'child'],
#  ['vulnerable',
#   'people',
#   'act',
#   'moral',
#   'act',
#   'instinct',
#   'fight',
#   'flight',
#   'mode',
#   'trying',
#   'survive',
#   'reality',
#   'crime',
#   'solved',
#   'people',
#   'simply',
#   'secure',
#   'source',
#   'food',
#   'shelter'],
#  ['legalise', 'period'],
#  ['seeing',
#   'comment',
#   'american',
#   'talking',
#   'shit',
#   'police',
#   'listen',
#   'yankies',
#   'police',
#   'force',
#   'world',
#   'apart',
#   'competent',
#   'kill',
#   'daily',
#   'trained',
#   'respected'],
#  ['true',
#   'government',
#   'bring',
#   'shit',
#   'money',
#   'turning',
#   'people',
#   'addict',
#   'heroin',
#   'epidemic',
#   'went',
#   'war',
#   'biggest',
#   'producer',
#   'poppy',
#   'world',
#   'afghanistan',
#   'raise',
#   'child',
#   'believe',
#   'fucked',
#   'brainwashed',
#   'school',
#   'race',
#   'shit',
#   'agenda',
#   'decade',
#   'tell',
#   'factual',
#   'think',
#   'racist',
#   'speaking',
#   'truth',
#   'look',
#   'white',
#   'bought',
#   'slave',
#   'north',
#   'africa',
#   'black',
#   'brought',
#   'slave',
#   'united',
#   'state',
#   'colony',
#   'formed',
#   'white',
#   'slave',
#   'bought',
#   'sold',
#   'ottoman',
#   'empire',
#   'decade',
#   'black',
#   'freed',
#   'united',
#   'state',
#   'brazil',
#   'country',
#   'western',
#   'world',
#   'abolish',
#   'slavery',
#   'time',
#   'abolished',
#   'estimated',
#   'million',
#   'slave',
#   'imported',
#   'africa',
#   'brazil',
#   'total',
#   'number',
#   'slave',
#   'brought',
#   'america',
#   'reference',
#   'united',
#   'state',
#   'received',
#   'percent',
#   'modern',
#   'slavery',
#   'brutal',
#   'reality',
#   'world',
#   'global',
#   'slavery',
#   'index',
#   'published',
#   'walk',
#   'free',
#   'foundation',
#   'estimate',
#   'million',
#   'people',
#   'form',
#   'slavery',
#   'country',
#   'percent',
#   'people',
#   'slavery',
#   'living',
#   'country',
#   'india',
#   'china',
#   'pakistan',
#   'bangladesh',
#   'uzbekistan',
#   'history',
#   'learn',
#   'school',
#   'bias',
#   'expect',
#   'people',
#   'accountability',
#   'thing',
#   'happened',
#   'born',
#   'especially',
#   'accountability',
#   'thing',
#   'today',
#   'african',
#   'slave',
#   'taken',
#   'africa',
#   'slavery',
#   'majority',
#   'atlantic',
#   'slave',
#   'trade',
#   'arab',
#   'slave',
#   'trade',
#   'look',
#   'million',
#   'taken',
#   'arab',
#   'slave',
#   'trade',
#   'million',
#   'survived',
#   'million',
#   'black',
#   'step',
#   'foot',
#   'arabic',
#   'land',
#   'genitals',
#   'cut',
#   'form',
#   'medication',
#   'antibiotic',
#   'help',
#   'woman',
#   'got',
#   'pregnant',
#   'let',
#   'baby',
#   'kill',
#   'woman',
#   'african',
#   'slave',
#   'died',
#   'arab',
#   'slave',
#   'trade',
#   'compared',
#   'atlantic',
#   'slave',
#   'trade',
#   'fact',
#   'mentioned',
#   'majority',
#   'black',
#   'today',
#   'believe',
#   'white',
#   'man',
#   'blame',
#   'clue',
#   'fact',
#   'brainwashed',
#   'white',
#   'feel',
#   'guilty',
#   'happened',
#   'thought',
#   'major',
#   'stereotype',
#   'going',
#   'elite',
#   'obviously',
#   'want',
#   'white',
#   'gone',
#   'think',
#   'going',
#   'happen',
#   'white',
#   'gone',
#   'look',
#   'country',
#   'white',
#   'slave',
#   'atlantic',
#   'slave',
#   'trade',
#   'went',
#   'brazil',
#   'caribbean',
#   'america',
#   'bear',
#   'majority',
#   'blame',
#   'slavery',
#   'america',
#   'majority',
#   'white',
#   'country',
#   'world',
#   'slave',
#   'came',
#   'america',
#   'lowest',
#   'majority',
#   'look',
#   'taught',
#   'school',
#   'ask',
#   'people',
#   'living',
#   'america',
#   'know',
#   'slavery',
#   'bet',
#   'know',
#   'speaking',
#   'black',
#   'owned',
#   'black',
#   'slave',
#   'land',
#   'look',
#   'man',
#   'legally',
#   'black',
#   'slave',
#   'america',
#   'anthony',
#   'johnson',
#   'black',
#   'man',
#   'wanted',
#   'slave',
#   'documented',
#   'people',
#   'need',
#   'wake',
#   'puppet',
#   'sting',
#   'played',
#   'like',
#   'fiddle',
#   'elite',
#   'elite',
#   'thinking',
#   'run',
#   'nation',
#   'criminal',
#   'monetary',
#   'choose',
#   'enslaved',
#   'today'],
#  ['like',
#   'soon',
#   'spends',
#   'time',
#   'game',
#   'left',
#   'ignorance',
#   'user',
#   'kind',
#   'regulation',
#   'place',
#   'point',
#   'life',
#   'addicted',
#   'heroin',
#   'year',
#   'youth',
#   'worship',
#   'leader',
#   'studied',
#   'discipleship',
#   'absolutely',
#   'anybody',
#   'caught',
#   'evil',
#   'world',
#   'time',
#   'compassion',
#   'understanding',
#   'step',
#   'forward',
#   'life',
#   'potential',
#   'value',
#   'minus',
#   'child',
#   'predator'],
#  ['whaaaaaat',
#   'mean',
#   'war',
#   'drug',
#   'racist',
#   'endeavor',
#   'shit',
#   'sherlock'],
#  ['roflmao', 'english', 'people', 'worst'],
#  ['interesting', 'he', 'american'],
#  ['fuckin', 'narc'],
#  ['scroll', 'see', 'channel', 'vice', 'flag', 'leaf'],
#  ['problem',
#   'legalising',
#   'illegal',
#   'drug',
#   'government',
#   'won',
#   'money',
#   'instance',
#   'uk',
#   'border',
#   'looked',
#   'gear',
#   'getting',
#   'higher',
#   'ups',
#   'letting',
#   'war',
#   'afghan',
#   'sure',
#   'kept',
#   'planting',
#   'poppy',
#   'ain',
#   'making',
#   'logic',
#   'yrselves'],
#  ['wheres', 'rest', 'interview'],
#  ['think', 'safe', 'come', 'brag', 'snitching', 'he'],
#  ['need', 'decriminalize', 'drug', 'criminal', 'police'],
#  ['quickly', 'vulnerable', 'people', 'use'],
#  ['unanswered',
#   'question',
#   'use',
#   'undercover',
#   'deal',
#   'keeping',
#   'focused',
#   'job'],
#  ['people',
#   'voting',
#   'conservative',
#   'right',
#   'wing',
#   'll',
#   'end',
#   'war',
#   'liberty'],
#  ['spice', 'drug', 'chemically', 'neuter', 'people', 'problem', 'solve'],
#  [],
#  ['british',
#   'cop',
#   'blaming',
#   'southern',
#   'black',
#   'mexican',
#   'drug',
#   'policy',
#   'uk',
#   'problem',
#   'usa'],
#  ['harm',
#   'reduction',
#   'cheaper',
#   'effective',
#   'ruin',
#   'life',
#   'people',
#   'family',
#   'affected',
#   'crime',
#   'drug',
#   'lot',
#   'country',
#   'stepping',
#   'right',
#   'direction',
#   'legalizing',
#   'marijuna'],
#  ['spent', 'life', 'lying', 'belief'],
#  ['guy', 'psychopath'],
#  ['piece', 'shit'],
#  ['waycissim',
#   'look',
#   'uploader',
#   'sound',
#   'like',
#   'libshit',
#   'fake',
#   'new',
#   'loool'],
#  ['vice'],
#  ['excellent',
#   'piece',
#   'vice',
#   'ish',
#   'strictly',
#   'uk',
#   'early',
#   'day',
#   'way',
#   'support',
#   'contra',
#   'fighting',
#   'sandinistas',
#   'little',
#   'secret',
#   'thing',
#   'started',
#   'little',
#   'government',
#   'agency',
#   'called',
#   'central',
#   'intelligence',
#   'agency',
#   'extremely',
#   'secretive',
#   'decided',
#   'shipping',
#   'gun',
#   'people',
#   'fight',
#   'communist',
#   'kinda',
#   'fly',
#   'home',
#   'cocaine',
#   'laiden',
#   'airplane',
#   'sell',
#   'home',
#   'black',
#   'community',
#   'start',
#   'sc',
#   'la',
#   'bam',
#   'way',
#   'pay',
#   'war',
#   'start',
#   'war',
#   'drug',
#   'smh',
#   'government',
#   'create',
#   'fucken',
#   'monster',
#   'insatiable',
#   'unquenchable',
#   'thirst',
#   'drug',
#   'money',
#   'south',
#   'america',
#   'follow',
#   'trend',
#   'america',
#   'closely',
#   'canada',
#   'europe',
#   'originally',
#   'dealt',
#   'cannabis',
#   'cocaine',
#   'little',
#   'bit',
#   'black',
#   'tar',
#   'heroin',
#   'major',
#   'shipment',
#   'powder',
#   'usually',
#   'brown',
#   'amd',
#   'white',
#   'color',
#   'methamphetamine',
#   'shard',
#   'rot',
#   'kill',
#   'as',
#   'drug',
#   'cannabis',
#   'verge',
#   'bigger',
#   'alcohol',
#   'hoping',
#   'verge',
#   'government',
#   'need',
#   'figure',
#   'going',
#   'going',
#   'regulate',
#   'tax',
#   'cash',
#   'fuck',
#   'people',
#   'people',
#   'voted',
#   'unanimously',
#   'seriously',
#   'state',
#   'need',
#   'board',
#   'going',
#   'boost',
#   'economy',
#   'going',
#   'buy',
#   'future',
#   'smoke',
#   'cook',
#   'drink',
#   'pill',
#   'strip',
#   'similar',
#   'suboxone',
#   'rub',
#   'skin',
#   'waste',
#   'material',
#   'waste',
#   'material',
#   'turned',
#   'clothing',
#   'basically',
#   'nice',
#   'sturdy',
#   'strong',
#   'cloth',
#   'wanna',
#   'use',
#   'cloth',
#   'paper',
#   'rope',
#   'strong',
#   'rope',
#   'cheap',
#   'rope',
#   'aka',
#   'hemp',
#   'government',
#   'need',
#   'thier',
#   'mouth',
#   'cannabis',
#   'control',
#   'commission',
#   'ridic',
#   'ready',
#   'long',
#   'time',
#   'ago',
#   'voting',
#   'past',
#   'got',
#   'best',
#   'story',
#   'cop',
#   'drug',
#   'gang',
#   'suck',
#   'wanna',
#   'tommy',
#   'mortan',
#   'fucken',
#   'trap',
#   'house',
#   'cooking',
#   'crack',
#   'ak',
#   'loaded',
#   'pointed',
#   'camera',
#   'whyy'],
#  [],
#  ['omg', 'guy', 'busted', 'badger', 'bus', 'stop', 'breaking', 'bad'],
#  ['ex',
#   'drug',
#   'dealer',
#   'convicted',
#   'criminal',
#   'man',
#   'said',
#   'point',
#   'argument'],
#  ['agree',
#   'said',
#   'changing',
#   'drug',
#   'law',
#   'safe',
#   'money',
#   'cartel',
#   'pocket',
#   'win',
#   'win'],
#  ['incredible', 'wise', 'man'],
#  ['lol', 'isn', 'cop', 'mexico', 'liberal', 'agenda', 'vice'],
#  ['flow',
#   'drug',
#   'going',
#   'stop',
#   'know',
#   'want',
#   'help',
#   'people',
#   'active',
#   'addiction',
#   'need',
#   'rehabilitate',
#   'incarcerate'],
#  ['thought', 'going', 'american', 'cop'],
#  ['ma', 'guy'],
#  ['expect',
#   'enjoyed',
#   'manipulating',
#   'people',
#   'maintaining',
#   'lie',
#   'caught',
#   'guard'],
#  ['woke',
#   'took',
#   'phone',
#   'opened',
#   'youtube',
#   'read',
#   'ex',
#   'undercover',
#   'drug',
#   'cop',
#   'explain',
#   'going',
#   'snitch',
#   'like'],
#  ['reform', 'drug', 'policy', 'fuckin', 'yesterday', 'love', 'gawd'],
#  ['watch', 'vice', 'good', 'going', 'far', 'left', 'guy'],
#  [],
#  ['need', 'subscriber', 'got'],
#  ['scum'],
#  ['vice',
#   'pushing',
#   'racism',
#   'b',
#   'propaganda',
#   'like',
#   'buzzfeed',
#   'remember',
#   'vice',
#   'cool',
#   'normie'],
#  ['sure', 'knew', 'undercover'],
#  ['snitch'],
#  ['heck', 'edited', 'question', 'need', 'stay', 'screen', 'double', 'time'],
#  ['utter',
#   'lie',
#   'british',
#   'american',
#   'reason',
#   'drug',
#   'banned',
#   'england',
#   'banned',
#   'drug',
#   'reasoning',
#   'wasn',
#   'fucking',
#   'mexican',
#   'real',
#   'number'],
#  ['snitch'],
#  ['self', 'respecting', 'junkie', 'lil', 'bit', 'dope', 'money', 'period'],
#  ['racism', 'statement', 'make', 'absolutely', 'sense', 'whatsoever'],
#  ['chap',
#   'politics',
#   'uk',
#   'need',
#   'mp',
#   'knowledge',
#   'maybe',
#   'educate',
#   'politician',
#   'real',
#   'world',
#   'like',
#   'reform',
#   'needed'],
#  ['guy',
#   'hhhhhhh',
#   'release',
#   'year',
#   'tension',
#   'face',
#   'insanity',
#   'know',
#   'long',
#   'way',
#   'policeman',
#   'talking',
#   'objective',
#   'sense',
#   'opinion'],
#  ['cannabis',
#   'specie',
#   'marijuana',
#   'hemp',
#   'cannabis',
#   'necessarily',
#   'marijuana',
#   'marijuana',
#   'definitely',
#   'cannabis'],
#  ['seen', 'interview'],
#  ['fake'],
#  ['people',
#   'criticising',
#   'labelling',
#   'sociopath',
#   'realise',
#   'job',
#   'detaching',
#   'difference',
#   'true',
#   'sociopath',
#   'good',
#   'learn',
#   'like',
#   'aspect',
#   'job',
#   'absolutely',
#   'unbearable',
#   'coping',
#   'mechanism'],
#  ['amaizing',
#   'video',
#   'learned',
#   'explains',
#   'drug',
#   'problem',
#   'possible',
#   'solution',
#   'video',
#   'coming',
#   'great'],
#  ['smart', 'dangerous'],
#  ['upload',
#   'getting',
#   'intense',
#   'deja',
#   'vu',
#   'right',
#   'think',
#   've',
#   'seen',
#   'video'],
#  ['wow',
#   'like',
#   'guy',
#   'know',
#   'wasted',
#   'year',
#   'life',
#   'feel',
#   'bad',
#   'people',
#   'fucked',
#   'need',
#   'run',
#   'prim',
#   'minister',
#   'uk'],
#  ['finally', 'good', 'vid'],
#  ['super', 'real', 'talk'],
#  ['rat'],
#  ['preach', 'mah', 'dude'],
#  ['course', 'vice', 'pushing', 'racist', 'narrative'],
#  ['race', 'heard', 'horse', 'mouth', 'white', 'supremacy', 'real', 'alive'],
#  ['liked',
#   'brutally',
#   'honest',
#   'enjoying',
#   'lying',
#   'manipulating',
#   'people',
#   'easy',
#   'fake',
#   'empathy',
#   'feel',
#   'bad',
#   'heart',
#   'clearly',
#   'honestly',
#   'dude',
#   'sociopath',
#   'seeing',
#   'lying',
#   'manipulation',
#   'career',
#   'excel'],
#  ['ive', 'seen', 'like', 'year', 'ago'],
#  ['old', 'video', 'saw', 'month', 'ago'],
#  ['read', 'guy', 'book', 'good'],
#  ['damn', 'feel', 'good', 'white'],
#  ['sociopath', 'yes', 'youve', 'got', 'job'],
#  ['thats', 'happened', 'pee', 'wee', 'herman'],
#  ['ah', 'beautiful', 'manipulation', 'deception'],
#  ['woo', 'showing', 'shit', 'northampton'],
#  ['make',
#   'sound',
#   'like',
#   'social',
#   'work',
#   'constantly',
#   'dangerous',
#   'impossible',
#   'imagine',
#   'stressful',
#   'family',
#   'paranoia',
#   'reality',
#   'fused',
#   'amazing',
#   'extremely',
#   'important',
#   'work',
#   'thank',
#   'sir'],
#  ['finally',
#   'vice',
#   'telling',
#   'truth',
#   'need',
#   'keep',
#   'putting',
#   'group',
#   'identity',
#   'propaganda'],
#  ['vice', 'isn', 'reloaded'],
#  ['interesting',
#   'consider',
#   'life',
#   'work',
#   'entirely',
#   'futile',
#   'modern',
#   'thought',
#   'legalize',
#   'narcotic',
#   'interesting',
#   'contention',
#   'use',
#   'sound',
#   'like',
#   'guess',
#   'use',
#   'alcohol',
#   'prohibition',
#   'relaxed',
#   'legalization',
#   'come',
#   'restriction',
#   'black',
#   'market',
#   'want',
#   'jump',
#   'hoop',
#   'social',
#   'control',
#   'course',
#   'people',
#   'wouldn',
#   'counted',
#   'overall',
#   'statistic',
#   'strongest',
#   'argument',
#   'favor',
#   'legalization',
#   'collapse',
#   'fentanyl',
#   'market',
#   'anticipated',
#   'decline',
#   'crime',
#   'increase',
#   'employment',
#   'dispense',
#   'monitor',
#   'drug',
#   'use',
#   'offset',
#   'dramatically',
#   'lower',
#   'policing',
#   'cost',
#   'expecting',
#   'addict',
#   'regain',
#   'employment',
#   'sound',
#   'like',
#   'pipe',
#   'dream'],
#  ['alchohol',
#   'use',
#   'packaged',
#   'advertised',
#   'sold',
#   'celebrated',
#   'culture',
#   'decriminalise',
#   'drug',
#   'legalize',
#   'use',
#   'taking',
#   'trade',
#   'away',
#   'criminal',
#   'treating',
#   'use',
#   'medical',
#   'issue'],
#  ['use',
#   'harm',
#   'criminalisation',
#   'increase',
#   'harm',
#   'risk',
#   'people',
#   'choose',
#   'consume',
#   'drug',
#   'better',
#   'obtaining',
#   'open',
#   'criminal',
#   'market',
#   'mdma',
#   'case',
#   'point',
#   'relatively',
#   'safe',
#   'drug',
#   'taken',
#   'correctly',
#   'criminalisation',
#   'make',
#   'dangerous'],
#  ['spelunkerd', 'claim', 'use', 'decrease', 'point', 'crime', 'dramatically'],
#  ['wouldn', 'vice', 'race', 'card', 'b'],
#  ['regardless', 'rub', 'wrong', 'way', 'agree', 'thing', 'said'],
#  ['bet',
#   'notts',
#   'cartel',
#   'catch',
#   'scumbag',
#   'sooner',
#   'later',
#   'deal',
#   'severely',
#   'dead',
#   'man',
#   'walking',
#   'tbh'],
#  ['right',
#   'heroin',
#   'user',
#   'empathetic',
#   'boy',
#   'dope',
#   'sick',
#   'knew',
#   'cash',
#   'day',
#   'hit',
#   'needed',
#   'money',
#   'needed',
#   'odd',
#   'lol',
#   'drug',
#   'scene',
#   'involved',
#   'heroin',
#   'fucked',
#   'people',
#   'took',
#   'care'],
#  ['omg', 'believe', 'guy', 'pig'],
#  ['yawn'],
#  ['volume', 'video', 'low'],
#  ['heroin',
#   'fentany',
#   'anxiolitics',
#   'labeled',
#   'major',
#   'problem',
#   'yppl',
#   'affected',
#   'hol',
#   'racist',
#   'diatribe',
#   'hole'],
#  ['thats', 'intelligent', 'person'],
#  ['umm', 'uk', 'mexican', 'sad', 'vice', 'race', 'baiting', 'racist'],
#  ['dude',
#   'took',
#   'money',
#   'homeless',
#   'care',
#   'job',
#   'money',
#   've',
#   'us',
#   'money',
#   'police',
#   'care',
#   'conviction',
#   'people',
#   'tread',
#   'issue',
#   'plus',
#   've',
#   'seen',
#   'convict',
#   'convict',
#   'case',
#   'bed',
#   'trust',
#   've',
#   'person',
#   'saying',
#   've',
#   'respect',
#   'right',
#   'yeah',
#   'try',
#   'stop',
#   'drug',
#   'epidemic',
#   'correct',
#   'people',
#   'said',
#   'money',
#   'people',
#   'great'],
#  ['good', 'content', 'like'],
#  ['mr', 'brown', 'got', 'famously'],
#  ['fucker', 'like', 'need', 'pill', 'sleep', 'night'],
#  [],
#  ['sold', 'geer', 'knob', 'he', 'bang'],
#  ['idea',
#   'like',
#   'change',
#   'world',
#   'especially',
#   'needed',
#   'stuck',
#   'bizarre',
#   'private',
#   'prison',
#   'drug',
#   'war',
#   'ruin',
#   'life',
#   'side'],
#  ['ppl',
#   'like',
#   'da',
#   'one',
#   'dat',
#   'burn',
#   'hell',
#   'right',
#   'killer',
#   'rapist',
#   'thief',
#   'da',
#   'piece',
#   'dat',
#   'lied'],
#  ['british', 'putin'],
#  ['drug', 'drug', 'drug', 'vice', 'pack', 'meth', 'head'],
#  ['man',
#   'explains',
#   'came',
#   'realization',
#   'coworkers',
#   'child',
#   'childrens',
#   'child',
#   'damned',
#   'strange',
#   'punishment',
#   'reserved',
#   'worker',
#   'iniquity',
#   'bible',
#   'speaks',
#   'job'],
#  ['interested', 'bristish', 'cop'],
#  ['need', 'spread', 'widely', 'public', 'opinion', 'reflects', 'legislation'],
#  ['true', 'geordie', 'podcast'],
#  ['vice', 'finally', 'starting', 'good'],
#  ['hahaha', 'def', 'sociopaht', 'said', 'enjoyed', 'manipulating', 'people'],
#  ['taking', 'mickey'],
#  ['lot', 'drug', 'cop'],
#  ['legalize', 'drug'],
#  ['prostitution'],
#  ['guy', 'seen', 'real', 'shit'],
#  ['drug', 'war', 'racism', 'simplistic', 'way'],
#  ['saying',
#   'vice',
#   'make',
#   'good',
#   'video',
#   'good',
#   'video',
#   'video',
#   'support',
#   'opinion'],
#  ['thanks',
#   'clearing',
#   'wasn',
#   'sure',
#   'think',
#   'anymore',
#   'maybe',
#   'run',
#   'president'],
#  ['tore', 'thyen', 'yea', 'maybe'],
#  ['alway',
#   'racism',
#   'virtue',
#   'signalling',
#   'twat',
#   'coming',
#   'vice',
#   'radical',
#   'left',
#   'propaganda'],
#  ['sound', 'like', 'ex'],
#  ['weasel'],
#  ['snitch'],
#  ['drug', 'bad', 'mmmmkay'],
#  ['glad', 'po', 'pig', 'came', 'eventually', 'assume', 'know', 'said'],
#  ['eye', 'opening', 'shit'],
#  ['smart', 'cop'],
#  ['racism', 'basically', 'soo', 'true'],
#  ['job'],
#  ['million', 'sub', 'view', 'comment', 'wow'],
#  ['cost', 'god', 'damn', 'money', 'privitize', 'racist'],
#  ['people',
#   'need',
#   'drug',
#   'daily',
#   'life',
#   'reduce',
#   'violent',
#   'country',
#   'certain',
#   'state',
#   'legal',
#   'item',
#   'drug',
#   'problematic',
#   'human',
#   'legal',
#   'non',
#   'legal',
#   'usage'],
#  ['snitch', 'need', 'stitch'],
#  ['word'],
#  ['person',
#   'experience',
#   'realised',
#   'drug',
#   'need',
#   'produced',
#   'supplied',
#   'legally',
#   'option',
#   'war',
#   'drug',
#   'simply',
#   'working'],
#  ['sound',
#   'like',
#   'kind',
#   'job',
#   'man',
#   'mad',
#   'time',
#   'making',
#   'new',
#   'friend'],
#  ['snitch'],
#  ['fellah', 'sociopath'],
#  ['good'],
#  ['vice', 'vox', 'crock', 'difference', 'jus', 'click'],
#  ['disgusting', 'human'],
#  ['willing',
#   'believe',
#   'guy',
#   'uk',
#   'cop',
#   'london',
#   'south',
#   'oh',
#   'mean',
#   'south',
#   'america',
#   'mexican',
#   'smoking',
#   'weed',
#   'uk',
#   'oh',
#   'mean',
#   'virtue',
#   'signaled',
#   'intro'],
#  ['talkin', 'fed', 'probably'],
#  ['work',
#   'police',
#   'admin',
#   'department',
#   'club',
#   'bar',
#   'work',
#   'colleague',
#   'working',
#   'undercover',
#   'kinda',
#   'awkward'],
#  ['nice', 'kind', 'thing', 'vice', 'biased', 'socio', 'political', 'bullshit'],
#  ['shoved', 'cocaine', 'butt'],
#  ['racism', 'idiot'],
#  ['ahaha',
#   'trusted',
#   'man',
#   'drug',
#   'dealer',
#   'change',
#   'profession',
#   'absolute',
#   'wanka'],
#  ['actually', 'talked', 'sense', 'neat'],
#  ['good', 'job', 'vice', 'interesting'],
#  ['basically', 'admitted', 'he', 'sociopath', 'guy', 'shouldnt', 'cop'],
#  ['surprised', 'showing', 'face'],
#  ['listen', 'recommendation', 'policy', 'maker'],
#  ['giving',
#   'heroin',
#   'heroin',
#   'addict',
#   'reduce',
#   'use',
#   'reduce',
#   'crime',
#   'legal',
#   'won',
#   'reduce',
#   'use',
#   'll',
#   'promote',
#   'zero',
#   'repercussion',
#   'allowing',
#   'people',
#   'thing',
#   'make',
#   'incapable',
#   'functioning',
#   'member',
#   'society'],
#  ['snitch'],
#  ['ofcourse', 'drug'],
#  ['repost'],
#  ['agree',
#   'drug',
#   'policy',
#   'fight',
#   'drug',
#   'problem',
#   'regulating',
#   'profit',
#   'organized',
#   'crime',
#   'deal',
#   'government',
#   'regulating',
#   'use',
#   'drug',
#   'form',
#   'big',
#   'pharma',
#   'heavily',
#   'criminalize',
#   'user',
#   'dealer',
#   'substance',
#   'exposed',
#   'violence',
#   'end',
#   'brings',
#   'higher',
#   'burden',
#   'cost',
#   'society',
#   'united',
#   'state',
#   'privatized',
#   'prison',
#   'profit',
#   'people',
#   'yeah',
#   'want',
#   'drug',
#   'addict',
#   'people',
#   'lock',
#   'profit',
#   'saying',
#   'drug',
#   'legalized',
#   'tho'],
#  ['poor',
#   'persecuted',
#   'yardie',
#   'mexican',
#   'cartel',
#   'getting',
#   'discriminated',
#   'travesty'],
#  ['cop',
#   'hold',
#   'higher',
#   'standard',
#   'stoop',
#   'level',
#   'cartel',
#   'street',
#   'hoodlum',
#   'fight',
#   'water',
#   'sand',
#   'instead',
#   'effective',
#   'mess'],
#  ['racism',
#   'yeah',
#   'law',
#   'say',
#   'white',
#   'trafficking',
#   'cocaine',
#   'drug',
#   'legal'],
#  ['let', 'flex'],
#  ['kd', 'video', 'drug', 'bug', 'spary', 'paper', 'smoking'],
#  ['comment',
#   'drug',
#   'policy',
#   'regulation',
#   'intelligent',
#   'kind',
#   'person',
#   'gleefully',
#   'admit',
#   'manipulating',
#   'weak'],
#  ['call',
#   'crazy',
#   'need',
#   'legalize',
#   'drug',
#   'people',
#   'understand',
#   'biggest',
#   'cause',
#   'overdose',
#   'quality',
#   'quantity',
#   'unknown',
#   'chemical',
#   'crime',
#   'someday',
#   'people',
#   'wake',
#   'hopefully'],
#  ['oh', 'nice', 'comment', 'arent', 'disabled', 'video'],
#  ['damn', 'vice', 'tryna'],
#  ['ur', 'gonna', 'killed', 'telling', 'true', 'alias', 'name'],
#  ['sale'],
#  ['bunch', 'b'],
#  ['vice', 'think', 'documentary', 'salvia', 'post', 'link'],
#  ['mean', 'govt', 'legalize', 'heroin'],
#  ['smart', 'man'],
#  ['good', 'video', 'vice'],
#  ['weird', 'vice', 'disabled', 'comment', 'video'],
#  ['american',
#   'drug',
#   'racism',
#   'based',
#   'color',
#   'race',
#   'number',
#   'people',
#   'addicted',
#   'crime',
#   'committed',
#   'people',
#   'people',
#   'hispanic',
#   'black',
#   'black',
#   'hispanic',
#   'took',
#   'drug',
#   'wouldn',
#   'population',
#   'addicted',
#   'hit',
#   'white',
#   'population',
#   'opiate',
#   'important',
#   'numerically',
#   'bigger',
#   'pool',
#   'people',
#   'addicted',
#   'white',
#   'equal',
#   'black',
#   'hispanic',
#   'combined',
#   'wanna',
#   'upset',
#   'racist',
#   'issue',
#   'complain',
#   'cigarette',
#   'liquor',
#   'lottery',
#   'shit',
#   'food',
#   'marketing',
#   'shoved',
#   'poor',
#   'neighborhood',
#   'throat',
#   'work',
#   'inner',
#   'city',
#   'methadone',
#   'clinic',
#   'white',
#   'black',
#   'ratio',
#   'close',
#   'epidemic',
#   'white',
#   'problem',
#   'topic',
#   'crack',
#   'numerically',
#   'affected',
#   'people',
#   'treated',
#   'color',
#   'clinic',
#   'white',
#   'crack',
#   'counted',
#   'opiate',
#   'addicted'],
#  ['war', 'drug', 'lie'],
#  ['sound', 'white'],
#  ['know', 'pub', 'walked', 'past', 'way', 'town'],
#  ['wow', 'seen', 'honnest', 'guy'],
#  ['cool', 'video', 'weed'],
#  ['im',
#   'surprised',
#   'wasnt',
#   'inspired',
#   'tom',
#   'clansy',
#   'fucking',
#   'jack',
#   'ryan'],
#  ['start', 'video', 'race', 'baiting', 'disgusting', 'making', 'hate', 'vice'],
#  ['truth', 'mad', 'respect', 'man'],
#  ['left', 'pro', 'police', 'agree', 'right', 'vice', 'far', 'left'],
#  ['snitch'],
#  ['committee', 'putting', 'dare', 'sticker', 'starting', 'hitting', 'suburb'],
#  ['drug',
#   'law',
#   'logic',
#   'ruin',
#   'life',
#   'drug',
#   'going',
#   'ruin',
#   'life',
#   'putting',
#   'prison'],
#  ['alternative'],
#  ['lombardi', 'correct', 'way', 'dealing', 'issue', 'legalization'],
#  ['jake',
#   'waugh',
#   'better',
#   'solution',
#   'isolation',
#   'relocation',
#   'work',
#   'based',
#   'father',
#   'cop',
#   'experience'],
#  ['lombardi',
#   'ehh',
#   'better',
#   'solution',
#   'drug',
#   'people',
#   'hand',
#   'prisoner',
#   'drug',
#   'expect',
#   'america',
#   'drug',
#   'spend',
#   'billion',
#   'year',
#   'od',
#   'going',
#   'drug',
#   'available',
#   'waste',
#   'money',
#   'best',
#   'solution',
#   'legalization',
#   'allowing',
#   'government',
#   'regulate',
#   'tax',
#   'substance',
#   'like',
#   'alcohol',
#   'billion',
#   'saved',
#   'treatment',
#   'facility',
#   'actually',
#   'help',
#   'addict',
#   'unlike',
#   'prison',
#   'money',
#   'tax',
#   'better',
#   'citizen',
#   'od',
#   'drop',
#   'drug',
#   'wouldn',
#   'laced',
#   'main',
#   'cause',
#   'overdoses',
#   'government',
#   'tell',
#   'body',
#   'allow',
#   'use',
#   'drink',
#   'smoke',
#   'kill',
#   'ten',
#   'thousand',
#   'year',
#   'people',
#   'allowed',
#   'adderall',
#   'meth',
#   'pill',
#   'oxycodone',
#   'highly',
#   'addictive',
#   'kill',
#   'thousand',
#   'heroine',
#   'pill',
#   'positive',
#   'ending',
#   'war',
#   'drug',
#   'truth',
#   'positive',
#   'continuing',
#   'nonsense'],
#  ['like',
#   'vice',
#   'ex',
#   'cop',
#   'spew',
#   'propaganda',
#   'scummy',
#   'video',
#   'agree',
#   'point',
#   've',
#   'title',
#   'datsracist'],
#  ['smart', 'control', 'drug', 'dealer', 'boot', 'lower', 'tax'],
#  ['upload', 'know', 've', 'seen'],
#  ['sound', 'white'],
#  ['money',
#   'drug',
#   'war',
#   'think',
#   'people',
#   'directly',
#   'involved',
#   'combating',
#   'drug',
#   'crime'],
#  ['gov', 'came', 'term', 'marijuana', 'cannabis', 'mexican', 'bad'],
#  ['sold',
#   'fucking',
#   'obvious',
#   'narc',
#   'deserved',
#   'taken',
#   'lmao',
#   'obviously',
#   'sketchy'],
#  ['people',
#   'saying',
#   'cop',
#   'pretty',
#   'laughable',
#   'considering',
#   'likely',
#   'people',
#   'offended',
#   'hear',
#   'generalize',
#   'black',
#   'people',
#   'mexican',
#   'people',
#   'love',
#   'hate',
#   'cop',
#   'till',
#   'need',
#   'hide',
#   'like',
#   'little',
#   'bitch',
#   'till'],
#  ['guy', 'gov', 'drug', 'czar', 'policy'],
#  ['look', 'shit', 'information', 'common', 'knowledge', 'year'],
#  ['time',
#   'saw',
#   'marijuana',
#   'ruin',
#   'someone',
#   'life',
#   'right',
#   'police',
#   'sold'],
#  [],
#  ['absolutely',
#   'agree',
#   'decriminalize',
#   'regulate',
#   'focus',
#   'harm',
#   'reduction',
#   'criminalization',
#   'people',
#   'drug',
#   'use',
#   'control',
#   'life',
#   'treatment',
#   'jail',
#   'cost',
#   'tax',
#   'payer',
#   'effective',
#   'reducing',
#   'drug',
#   'use',
#   'portugal',
#   'model',
#   'reduced',
#   'nationwide',
#   'addiction',
#   'rate',
#   'significantly',
#   'illegal',
#   'market',
#   'anymore',
#   'drug',
#   'cartel',
#   'crumble',
#   'reduce',
#   'crime',
#   'reduce',
#   'drug',
#   'use',
#   'save',
#   'life',
#   'bodily',
#   'autonomy',
#   'people',
#   'cost',
#   'tax',
#   'side'],
#  ['jail', 'drug', 'control', 'life', 'treatment', 'isn', 'future'],
#  ['danielle',
#   'spargo',
#   'common',
#   'fucking',
#   'sense',
#   'way',
#   'forward',
#   'government',
#   'corrupt',
#   'care'],
#  ['democrat', 'cunt', 'listening', 'dipshit', 'hear', 'listening'],
#  ['switzerland',
#   'country',
#   'try',
#   'approach',
#   'incredible',
#   'drug',
#   'problem',
#   'nowadays',
#   'searching',
#   'human',
#   'relic',
#   'time',
#   'switzerland',
#   'portugal',
#   'shown',
#   'effective',
#   'better',
#   'way',
#   'handle',
#   'problem'],
#  ['democrat',
#   'cunt',
#   'putting',
#   'jail',
#   'life',
#   'continuing',
#   'jail',
#   'treat',
#   'make',
#   'absolutely',
#   'sense',
#   'know',
#   'majority',
#   'people',
#   'feel',
#   'way',
#   'jailing',
#   'releasing',
#   'know',
#   'right',
#   'long',
#   'cycle',
#   'continue',
#   'want',
#   'cycle',
#   'continue',
#   'gov',
#   'want',
#   'afford',
#   'crime',
#   'want',
#   'control',
#   'play',
#   'people',
#   'mind',
#   'reduce',
#   'crime',
#   'small',
#   'feel',
#   'difference',
#   'individual',
#   'mind',
#   'like',
#   'affect',
#   'america',
#   'economy',
#   'time',
#   'research',
#   'come',
#   'understand',
#   'crime',
#   'america',
#   'cash',
#   'cow',
#   'career',
#   'crime',
#   'hasn',
#   'hand',
#   'making',
#   'sure',
#   'career',
#   'continues',
#   'grow',
#   'cut',
#   'crime',
#   'affect',
#   'america',
#   'economy',
#   'crime',
#   'creates',
#   'job',
#   'job',
#   'generate',
#   'tax',
#   'tax',
#   'revenue',
#   'revenue',
#   'distributed',
#   'elected',
#   'official'],
#  ['agree', 'said', 'second', 'smh'],
#  ['danielle', 'spargo', 'said'],
#  ['guy',
#   'rid',
#   'heroin',
#   'epidemic',
#   'available',
#   'medical',
#   'use',
#   'll',
#   'away',
#   'illegal',
#   'distribution',
#   'abuse',
#   'isn',
#   'heroin',
#   'medically',
#   'altered',
#   'countless',
#   'case',
#   'patient',
#   'struggling',
#   'opiate',
#   'addiction',
#   'heroin',
#   'like',
#   'marijuana',
#   'lmao',
#   'gonna',
#   'big',
#   'business',
#   'big',
#   'pharma',
#   'oh',
#   'yeah',
#   'cop',
#   'wouldn',
#   'surprised',
#   'control',
#   'establishment',
#   'money',
#   'interest',
#   'bitch',
#   'danielle',
#   'easily',
#   'manipulated',
#   'baby'],
#  ['say', 'paid', 'life', 'ruined'],
#  ['alpha',
#   'orc',
#   'canada',
#   'moving',
#   'program',
#   'similar',
#   'government',
#   'challenged',
#   'court',
#   'effective',
#   'expanding'],
#  ['worksfor', 'baltimore', 'police', 'department', 'far', 'fun', 'er'],
#  ['watched', 'interview', 'guy', 'true', 'geordie', 'podcast'],
#  ['agree', 'fully'],
#  ['fucking', 'undy'],
#  ['age', 'ago', 'reposted'],
#  ['saw', 'month', 'ago', 'uploaded'],
#  ['mexican', 'uk'],
#  ['yep',
#   'mate',
#   'tottaly',
#   'right',
#   'check',
#   'portuguese',
#   'example',
#   'learn',
#   'bit'],
#  ['undercover',
#   'talk',
#   'camera',
#   'answer',
#   'question',
#   'make',
#   'hard',
#   'sent',
#   'jail',
#   'cut',
#   'head'],
#  ['wrong', 'racism'],
#  ['isn', 'cut', 'older', 'documentary', 'distinctly', 'remember', 'seeing'],
#  ['example',
#   'war',
#   'model',
#   'drug',
#   'abuse',
#   'prevention',
#   'make',
#   'sense',
#   'value',
#   'freedom',
#   'west',
#   'shrug',
#   'people',
#   'handle',
#   'like',
#   'functional',
#   'successful',
#   'people',
#   'use',
#   'drug',
#   'sly',
#   'punish',
#   'people',
#   'suffer',
#   'misuse',
#   'drug',
#   'abuse',
#   'like',
#   'poor',
#   'vulnerable'],
#  ['legalization',
#   'create',
#   'problem',
#   'edged',
#   'sword',
#   'general',
#   'people',
#   'tend',
#   'gravitate',
#   'illegal',
#   'stuff',
#   'drug',
#   'like',
#   'tobacco',
#   'alcohol'],
#  ['khondker',
#   'rifat',
#   'hossain',
#   'bunch',
#   'legal',
#   'addict',
#   'blowing',
#   'family',
#   'rent',
#   'food',
#   'money',
#   'cocaine',
#   'crack',
#   'continuing',
#   'abandon',
#   'child',
#   'illegal',
#   'front',
#   'doubt',
#   'accompany',
#   'legal',
#   'infrastructure',
#   'criminal',
#   'meet',
#   'demand',
#   'addict',
#   'won',
#   'able',
#   'afford',
#   'marked',
#   'dope',
#   'choking',
#   'illegitimate',
#   'market',
#   'need',
#   'foremost',
#   'priority',
#   'legalization',
#   'going',
#   'work'],
#  ['शक',
#   'dude',
#   'legal',
#   'addict',
#   'abandoning',
#   'family',
#   'blowing',
#   'rent',
#   'money',
#   'alcohol',
#   'gambling',
#   'opioid',
#   'problem',
#   'going',
#   'pain',
#   'killer',
#   'heroin',
#   'aren',
#   'opioids',
#   'banned',
#   'making',
#   'illegal',
#   'drug',
#   'legal',
#   'know',
#   'chemical',
#   'meth',
#   'legal',
#   'buy',
#   'addiction',
#   'going',
#   'problem',
#   'making',
#   'drug',
#   'legal',
#   'isn',
#   'going',
#   'turn',
#   'addict',
#   'addict',
#   'right',
#   'kid',
#   'buy',
#   'drug',
#   'making',
#   'legal',
#   'drop',
#   'crime',
#   'prison',
#   'rate',
#   'little',
#   'bit'],
#  ['stayed', 'subscribed', 'actual', 'content'],
#  ['yeah', 'movie', 'samurai', 'sword', 'scene', 'gold'],
#  ['isnt', 'reupload'],
#  ['fucking',
#   'said',
#   'man',
#   'fucking',
#   'said',
#   'hate',
#   'police',
#   'little',
#   'bit'],
#  ['politics',
#   'fight',
#   'cause',
#   'drug',
#   'use',
#   'instead',
#   'making',
#   'addict',
#   'life',
#   'worse'],
#  ['understand', 'jack', 'shit'],
#  ['like',
#   'cut',
#   'bullshit',
#   'say',
#   'straight',
#   'enjoyed',
#   'taking',
#   'advantage',
#   'people',
#   'lying',
#   'maintaining',
#   'lie'],
#  ['bro', 'sup', 'upload', 'saw', 'month', 'ago'],
#  ['worried', 'guy', 'safety'],
#  ['matter',
#   'drug',
#   'white',
#   'boy',
#   'girl',
#   'selling',
#   'care',
#   'second',
#   'whittie',
#   'complains',
#   'cause',
#   'making',
#   'money',
#   'look',
#   'cannabis',
#   'number',
#   'minority',
#   'jail',
#   'decade',
#   'sentence',
#   'weed',
#   'white',
#   'jail',
#   'crack',
#   'cocaine',
#   'meth',
#   'pill',
#   'like',
#   'life',
#   'long',
#   'whittie',
#   'ok'],
#  ['better', 'video', 'guy', 'smoking', 'lamp'],
#  ['piece',
#   'shit',
#   'enjoyed',
#   'fucking',
#   'vulnerable',
#   'sick',
#   'people',
#   'addicted',
#   'heroin',
#   'gave',
#   'quid',
#   'sure',
#   'knowing',
#   'quid',
#   'keep',
#   'getting'],
#  ['drug',
#   'dealer',
#   'locked',
#   'user',
#   'cuz',
#   'user',
#   'da',
#   'drug',
#   'jail',
#   'dealer',
#   'one',
#   'broken',
#   'family',
#   'ruining',
#   'people',
#   'life'],
#  ['thought', 'alchemist', 'thumbnail', 'lmao'],
#  ['racism',
#   'dont',
#   'believe',
#   'store',
#   'ask',
#   'dont',
#   'mix',
#   'white',
#   'brown',
#   'rice'],
#  ['coz', 'undercover', 'coooop'],
#  [],
#  ['interesting', 'like', 'depth'],
#  ['guy',
#   'neil',
#   'wood',
#   'ruined',
#   'lot',
#   'life',
#   'remorse',
#   'people',
#   'deserved',
#   'punishment',
#   'life',
#   'fucking',
#   'believable',
#   'come',
#   'go'],
#  ['swear', 'reupload', 'realized', 'told', 'shit', 'verbatim'],
#  ['skip', 'moronic', 'cop'],
#  ['racism', 'smfh'],
#  ['know',
#   'opium',
#   'problem',
#   'huge',
#   'black',
#   'mexican',
#   'opium',
#   'trade',
#   'destroyed',
#   'chinese',
#   'japanese',
#   'community',
#   'blanketed',
#   'statement',
#   'sense',
#   'factor',
#   'think',
#   'legalizing',
#   'controlling',
#   'horrible',
#   'idea',
#   'thousand',
#   'people',
#   'die',
#   'legal',
#   'opioids',
#   'yearly',
#   'explain',
#   'control',
#   'right'],
#  ['comment',
#   'puzzling',
#   'going',
#   'try',
#   'discussion',
#   'drug',
#   'prohibition',
#   'largely',
#   'related',
#   'racism',
#   'thing',
#   'sure',
#   'big',
#   'issue',
#   'opiods',
#   'new',
#   'generation',
#   'opiod',
#   'analgesic',
#   'painkiller',
#   'marketed',
#   'chemist',
#   'research',
#   'nearly',
#   'zero',
#   'addiction',
#   'extremely',
#   'wrong',
#   'doctor',
#   'trained',
#   'time',
#   'period',
#   'taught',
#   'new',
#   'painkiller',
#   'relatively',
#   'safe',
#   'came',
#   'dependency',
#   'reason',
#   'massive',
#   'prescription',
#   'opiod',
#   'painkiller',
#   'addicted',
#   'opiods',
#   'doctor',
#   'cut',
#   'prescription',
#   'dont',
#   'need',
#   'injury',
#   'anymore',
#   'suffer',
#   'withdrawal',
#   'people',
#   'simply',
#   'handle',
#   'decide',
#   'buy',
#   'heroin',
#   'consume',
#   'drug',
#   'street',
#   'heroin',
#   'especially',
#   'high',
#   'chance',
#   'drug',
#   'going',
#   'impure',
#   'cut',
#   'different',
#   'unknown',
#   'drug',
#   'fentanyl',
#   'reason',
#   'product',
#   'strong',
#   'sell',
#   'allowing',
#   'drug',
#   'dealer',
#   'profit',
#   'user',
#   'take',
#   'regular',
#   'dose',
#   'overdoses',
#   'overdose',
#   'drug',
#   'wasnt',
#   'regulated',
#   'drug',
#   'illegal',
#   'people',
#   'die',
#   'single',
#   'year',
#   'alcohol',
#   'overdose',
#   'drug',
#   'combined',
#   'including',
#   'bigger',
#   'people',
#   'got',
#   'drunk',
#   'stupid',
#   'wrecked',
#   'traffic',
#   'died',
#   'strictly',
#   'alcohol',
#   'overdoses',
#   'harm',
#   'reduction',
#   'different',
#   'approach',
#   'drug',
#   'use',
#   'arresting',
#   'people',
#   'locking',
#   'getting',
#   'stuck',
#   'inside',
#   'prison',
#   'felon',
#   'decent',
#   'job',
#   'felony',
#   'drug',
#   'possession',
#   'fucked',
#   'inform',
#   'use',
#   'drug',
#   'safely',
#   'know',
#   'addiction',
#   'help',
#   'dare',
#   'style',
#   'dont',
#   'drug',
#   'accept',
#   'certain',
#   'percentage',
#   'people',
#   'going',
#   'use',
#   'drug',
#   'minimize',
#   'harm',
#   'come',
#   'werent',
#   'aware',
#   'weed',
#   'lsd',
#   'shrooms',
#   'heroin',
#   'assuming',
#   'pure',
#   'overdose',
#   'literally',
#   'safer',
#   'body',
#   'tobacco',
#   'alcohol',
#   'drug',
#   'law',
#   'arent',
#   'protect',
#   'people',
#   'happened',
#   'causing',
#   'ton',
#   'issue',
#   'disregarding',
#   'hypothetical',
#   'want',
#   'know',
#   'actually',
#   'happens',
#   'nation',
#   'decriminalizes',
#   'drug',
#   'look',
#   'portugal',
#   'seen',
#   'massive',
#   'reduction',
#   'drug',
#   'addiction',
#   'rate',
#   'drug',
#   'related',
#   'death',
#   'drug',
#   'illegal',
#   'violent',
#   'gang',
#   'come',
#   'play',
#   'product',
#   'sketchy',
#   'thing',
#   'safe',
#   'information',
#   'scarce',
#   'illegal'],
#  ['intramental',
#   'studio',
#   'statement',
#   'sided',
#   'seen',
#   'ton',
#   'people',
#   'prescription',
#   'purpose',
#   'getting',
#   'high',
#   'addicted',
#   'explain',
#   'help',
#   'decriminalize',
#   'drug',
#   'sure',
#   'parent',
#   'child',
#   'wanted',
#   'smoke',
#   'drug',
#   'allowed',
#   'think',
#   'good',
#   'idea',
#   'argument',
#   'according',
#   'cop',
#   'said',
#   'drug',
#   'illegal',
#   'racism',
#   'true',
#   'illegal',
#   'destroyed',
#   'family',
#   'example',
#   'chinese',
#   'illegal',
#   'opium',
#   'trade',
#   'destroyed',
#   'family',
#   'race',
#   'maybe',
#   'little',
#   'research',
#   'plenty',
#   'country',
#   'drug',
#   'illegal',
#   'destroyed',
#   'life',
#   'race',
#   'uk',
#   'make',
#   'illegal',
#   'heroine',
#   'meth',
#   'thing',
#   'argument',
#   'sided',
#   'conspiracy',
#   'racism',
#   'friend',
#   'say',
#   'like',
#   'xanax',
#   'feel',
#   'good',
#   'alcohol',
#   'white',
#   'caught',
#   'bottle',
#   'charged',
#   'felony',
#   'adult',
#   'isn',
#   'addicted',
#   'like',
#   'pop',
#   'mg',
#   'away',
#   'yeah',
#   'counting',
#   'day',
#   'apologize',
#   'punctuation',
#   'iphone',
#   'people',
#   'need',
#   'stop',
#   'racism',
#   'crap'],
#  ['feel',
#   'drug',
#   'law',
#   'place',
#   'racism',
#   'today',
#   'time',
#   'year',
#   'ago',
#   'news',
#   'report',
#   'early',
#   'clearly',
#   'strange',
#   'story',
#   'case',
#   'yellow',
#   'journalism',
#   'harrison',
#   'narcotic',
#   'tax',
#   'act',
#   'federal',
#   'law',
#   'place',
#   'response',
#   'event',
#   'drafter',
#   'played',
#   'fear',
#   'drug',
#   'crazed',
#   'sex',
#   'mad',
#   'negro',
#   'reference',
#   'negro',
#   'influence',
#   'drug',
#   'murdering',
#   'white',
#   'degenerate',
#   'mexican',
#   'smoking',
#   'marijuana',
#   'chinaman',
#   'seducing',
#   'white',
#   'woman',
#   'drug',
#   'dr',
#   'hamilton',
#   'wright',
#   'testified',
#   'hearing',
#   'harrison',
#   'act',
#   'wright',
#   'alleged',
#   'drug',
#   'black',
#   'uncontrollable',
#   'gave',
#   'superhuman',
#   'power',
#   'caused',
#   'rebel',
#   'white',
#   'authority',
#   'dr',
#   'christopher',
#   'koch',
#   'state',
#   'pharmacy',
#   'board',
#   'pennsylvania',
#   'testified',
#   'attack',
#   'white',
#   'woman',
#   'south',
#   'direct',
#   'result',
#   'cocaine',
#   'crazed',
#   'negro',
#   'brain',
#   'http',
#   'en',
#   'wikipedia',
#   'org',
#   'wiki',
#   'trying',
#   'push',
#   'conspiracy',
#   'thing',
#   'discussing',
#   'truly',
#   'fact',
#   'saying',
#   'reason',
#   'big',
#   'reason',
#   'isnt',
#   'racism',
#   'attack',
#   'counter',
#   'culture',
#   'movement',
#   'anti',
#   'war',
#   'protester',
#   'racial',
#   'revolutionary',
#   'group',
#   'like',
#   'black',
#   'panther',
#   'direct',
#   'statement',
#   'john',
#   'ehrlichman',
#   'counsel',
#   'assistant',
#   'president',
#   'domestic',
#   'affair',
#   'president',
#   'richard',
#   'nixon',
#   'quoted',
#   'year',
#   'nixon',
#   'campaign',
#   'nixon',
#   'white',
#   'house',
#   'enemy',
#   'antiwar',
#   'left',
#   'black',
#   'people',
#   'understand',
#   'saying',
#   'knew',
#   'couldn',
#   'illegal',
#   'war',
#   'black',
#   'getting',
#   'public',
#   'associate',
#   'hippy',
#   'marijuana',
#   'black',
#   'heroin',
#   'criminalizing',
#   'heavily',
#   'disrupt',
#   'community',
#   'arrest',
#   'leader',
#   'raid',
#   'home',
#   'break',
#   'meeting',
#   'vilify',
#   'night',
#   'night',
#   'evening',
#   'news',
#   'know',
#   'lying',
#   'drug',
#   'course',
#   'agree',
#   'issue',
#   'racism',
#   'racism',
#   'people',
#   'think',
#   'problem',
#   'rooted',
#   'racism',
#   'asking',
#   'set',
#   'association',
#   'opinion',
#   'aside',
#   'separate',
#   'real',
#   'issue',
#   'reason',
#   'passionate',
#   'putting',
#   'information',
#   'youtube',
#   'central',
#   'issue',
#   'career',
#   'field',
#   've',
#   'considerably',
#   'research',
#   'average',
#   'believe',
#   'problem',
#   'hopefully',
#   'improve',
#   'people',
#   'need',
#   'understand',
#   'true',
#   'factor',
#   'play'],
#  ['intramental', 'studio', 'saying', 'argue', 'fact', 'post', 'argument'],
#  ['sociopath'],
#  ['kick', 'jooz', 'lose'],
#  ['bullshit'],
#  ['horrible', 'ppl', 'job'],
#  ['excellent', 'content', 'love', 'kind', 'intriguing', 'vids'],
#  ['guy', 'like', 'manipulate', 'people', 'vice', 'fell', 'lot', 'bullshit'],
#  ['like', 'vice', 'start', 'video', 'classic', 'race', 'baiting'],
#  ['wow',
#   'man',
#   'need',
#   'write',
#   'book',
#   'story',
#   'guy',
#   'suicide',
#   'watch',
#   'heartbreaking'],
#  ['surprised',
#   'vice',
#   'turned',
#   'narcotic',
#   'supporting',
#   'organization',
#   'funding',
#   'mexican',
#   'drug',
#   'cartel'],
#  ['decriminalize',
#   'legalize',
#   'drug',
#   'literally',
#   'take',
#   'money',
#   'away',
#   'drug',
#   'cartel',
#   'gang',
#   'gang',
#   'illegal',
#   'drug',
#   'legal',
#   'people',
#   'safer',
#   'general'],
#  ['intramental',
#   'studio',
#   'like',
#   'war',
#   'legalize',
#   'drug',
#   'alot',
#   'money',
#   'doubt',
#   'play',
#   'nice',
#   'plus',
#   'drug',
#   'constantly',
#   'changed',
#   'black',
#   'market',
#   'better',
#   'worse',
#   'need',
#   'best',
#   'case',
#   'scenario',
#   'like',
#   'table',
#   'deal',
#   'pill',
#   'martin',
#   'shekli',
#   'want'],
#  ['lmao',
#   'said',
#   'cannabis',
#   'wasn',
#   'problem',
#   'mexican',
#   'immigrant',
#   'cannabis',
#   'problem',
#   'illegal',
#   'kill',
#   'methanol',
#   'industry',
#   'threatened',
#   'big',
#   'oil',
#   'war',
#   'drug',
#   'bullshit',
#   'war',
#   'competition',
#   'keep',
#   'prison'],
#  ['lol',
#   'dumb',
#   'say',
#   'wasn',
#   'problem',
#   'meant',
#   'viewed',
#   'problem',
#   'opinion',
#   'opinion',
#   'change',
#   'follow',
#   'fact',
#   'dip'],
#  ['smart', 'huh'],
#  ['kinda', 'dense', 'huh'],
#  ['dark',
#   'senator',
#   'he',
#   'telling',
#   'truth',
#   'hemp',
#   'cannabis',
#   'people',
#   'loose',
#   'lot',
#   'money',
#   'thats',
#   'illegal'],
#  ['mexican',
#   'uk',
#   'cop',
#   'year',
#   'ago',
#   'cry',
#   'asian',
#   'gang',
#   'growing',
#   'indoor',
#   'skunk',
#   'herb',
#   'lie',
#   'say',
#   'mexican',
#   'mexican',
#   'lost',
#   'quality',
#   'decade',
#   'ago',
#   'american',
#   'amsterdam',
#   'people',
#   'running',
#   'global',
#   'cannabis',
#   'decade',
#   'real',
#   'weed',
#   'illegal',
#   'oil',
#   'dupont',
#   'textile',
#   'like',
#   'polyster',
#   'cannabis',
#   'hemp',
# ...
#   'walmart',
#   'neighbor',
#   'hood',
#   'supermarket',
#   'kidnapping',
#   'coworkers',
#   'setting',
#   'shooting',
#   'manager',
#   'getting',
#   'cart',
#   'pusher',
#   'locked',
#   'cart',
#   'oh',
#   'forget',
#   'turning',
#   'eatchothers',
#   'mom',
#   'sister',
#   'product'],
#  ['criminal', 'profit', 'care', 'law', 'want', 'profit'],
#  ['opposite'],
#  ['good',
#   'theory',
#   'user',
#   'bad',
#   'planner',
#   'life',
#   'chaotic',
#   'regulation',
#   'require',
#   'registration',
#   'obtain',
#   'drug',
#   'gap',
#   'market',
#   'illegal',
#   'supplier',
#   'exploit',
#   'user',
#   'need',
#   'instant',
#   'fix',
#   'sure',
#   'way',
#   'aspect',
#   'problem'],
#  ['cause', 'heroin', 'legal', 'dosnt', 'mean', 'going', 'forced'],
#  ['david',
#   'goresh',
#   'know',
#   'fuck',
#   'requirement',
#   'register',
#   'require',
#   'unknown',
#   'reason',
#   'people',
#   'register',
#   'hard',
#   'thing',
#   'addict',
#   'doctor',
#   'opiate',
#   'withdrawal',
#   'medication',
#   'signing',
#   'paper',
#   'harder',
#   'think',
#   'thought'],
#  ['street'],
#  ['nytonpeliaika',
#   'street',
#   'think',
#   'trillion',
#   'spent',
#   'eliminate',
#   'drug',
#   'money',
#   'plus',
#   'money',
#   'saved',
#   'private',
#   'public',
#   'prison',
#   'omg',
#   'money',
#   'better',
#   'drug',
#   'street',
#   'cost',
#   'trillion',
#   'v',
#   'thing',
#   'free',
#   'll',
#   'free'],
#  ['absolutely',
#   'agreed',
#   'counter',
#   'intuitive',
#   'reduces',
#   'drug',
#   'abuse',
#   'drug',
#   'death',
#   'tax',
#   'payer',
#   'expense',
#   'remove',
#   'primary',
#   'revenue',
#   'stream',
#   'drug',
#   'cartel',
#   'terrorizing',
#   'south',
#   'america',
#   'use',
#   'generate',
#   'tax',
#   'revenue',
#   'like',
#   'marijuana',
#   'industry',
#   'state',
#   'providing',
#   'million',
#   'dollar',
#   'total',
#   'legalization',
#   'better',
#   'step',
#   'discussion',
#   'position',
#   'currently',
#   'sit',
#   'locking',
#   'people',
#   'jail',
#   'costing',
#   'tax',
#   'payer',
#   'million',
#   'letting',
#   'die',
#   'injecting',
#   'unregulated',
#   'fentanyl',
#   'laced',
#   'drug',
#   'giving',
#   'cartel',
#   'money',
#   'need',
#   'dominate',
#   'continent'],
#  ['adam',
#   'cantrell',
#   'portugal',
#   'implemented',
#   'similar',
#   'significantly',
#   'reduced',
#   'drug',
#   'use',
#   'treatment',
#   'cheaper',
#   'tax',
#   'payer',
#   'prison',
#   'far',
#   'effective',
#   'reducing',
#   'usage',
#   've',
#   'seen',
#   'america',
#   'clean',
#   'needle',
#   'program',
#   'significantly',
#   'reduced',
#   'spread',
#   'hepatitis',
#   'hiv',
#   'unfortunately',
#   'program',
#   'haven',
#   'adopted',
#   'country',
#   'understand',
#   'counter',
#   'intuitive',
#   'work',
#   'reduce',
#   'drug',
#   'usage',
#   'seen',
#   'effective',
#   'implemented',
#   'actual',
#   'real',
#   'world',
#   'understand',
#   'hesitent',
#   'fear',
#   'unfounded',
#   'based',
#   'false',
#   'premise',
#   'street',
#   'flooded',
#   'drug',
#   'dirty',
#   'impure',
#   'killing',
#   'user',
#   'think',
#   'buying',
#   'need',
#   'change',
#   'horrible',
#   'black',
#   'situation',
#   'described',
#   'exists',
#   'current',
#   'paradigm',
#   'clearly',
#   'effective'],
#  ['legal', 'mean', 'people', 'going'],
#  ['war', 'drug', 'war', 'personal', 'freedom'],
#  ['understand',
#   'feel',
#   'way',
#   'evidence',
#   'support',
#   'google',
#   'amaze',
#   'known',
#   'year',
#   'guess',
#   'joe',
#   'rogan',
#   'joey',
#   'diaz',
#   'podcast',
#   'run',
#   'hill',
#   'work',
#   'daily',
#   'time',
#   'comedian',
#   'hit',
#   'tv',
#   'show',
#   'avid',
#   'hunter',
#   'disproved'],
#  ['shouldn',
#   'promotes',
#   'drug',
#   'addiction',
#   'normal',
#   'individual',
#   'susceptible',
#   'non',
#   'functioning',
#   'welfare',
#   'addict'],
#  ['jonnybaze',
#   'got',
#   'ooffed',
#   'pretty',
#   'regulated',
#   'safely',
#   'mean',
#   'drug',
#   'available',
#   'need',
#   'badly'],
#  ['garrett', 'like', 'buck', 'dip', 'canada', 'going'],
#  ['christopher',
#   'brown',
#   'dip',
#   'huh',
#   'doubt',
#   'canadian',
#   'care',
#   'chewing',
#   'tobacco',
#   'plus',
#   'guy',
#   'chew',
#   'oil',
#   'rig',
#   'afford',
#   'dip',
#   'afford',
#   'shitty',
#   'ram',
#   'lifted'],
#  ['garrett',
#   'im',
#   'saying',
#   'tobacco',
#   'expensive',
#   'couldn',
#   'imagine',
#   'harder',
#   'drug',
#   'price',
#   'range'],
#  ['democrat',
#   'cunt',
#   'evidence',
#   'support',
#   'evidence',
#   'contrary',
#   'promotes',
#   'locking',
#   'people',
#   'hurting',
#   'trillion',
#   'saved',
#   'education',
#   'extreme',
#   'high',
#   'lowering',
#   'number',
#   'susceptible',
#   'people',
#   'greatly',
#   'increase',
#   'treatment',
#   'treatment',
#   'option',
#   'anti',
#   'democrat',
#   'wouldn',
#   'smaller',
#   'government',
#   'reduced',
#   'power'],
#  ['christopher', 'brown', 'people', 'buy', 'think', 'expensive'],
#  ['jonnybaze',
#   'stuck',
#   'talking',
#   'point',
#   'repubs',
#   'dems',
#   'glad',
#   'tge',
#   'paradimn',
#   'going',
#   'away',
#   'party',
#   'people',
#   'vote',
#   'anymore',
#   'point',
#   'corrupt',
#   'politician',
#   'office'],
#  ['thomas',
#   'sawyer',
#   'talking',
#   'point',
#   'opinion',
#   'based',
#   'evidence',
#   'ik',
#   'said',
#   'untrue',
#   'party',
#   'thousand',
#   'people',
#   'run',
#   'president',
#   'people',
#   'vote',
#   'exclusively',
#   'vote',
#   'dem',
#   'rep',
#   'stupid'],
#  ['christopher',
#   'brown',
#   'weed',
#   'bc',
#   'cheap',
#   'working',
#   'class',
#   'afford',
#   'weed',
#   'say',
#   'regulated',
#   'hard',
#   'drug',
#   'cost',
#   'addict',
#   'universal',
#   'health',
#   'care',
#   'want',
#   'help',
#   'poor',
#   'mentality',
#   'ill',
#   'issue',
#   'wouldn',
#   'charge',
#   'outrageous',
#   'price',
#   'lab',
#   'heroin',
#   'know',
#   'chewing',
#   'tobacco',
#   'non',
#   'issue',
#   'canada',
#   'brought',
#   'drug',
#   'debate',
#   'tobacco',
#   'irrelevant',
#   'hard',
#   'street',
#   'drug',
#   'addiction',
#   'dealing'],
#  ['errl',
#   'shmirl',
#   'gone',
#   'bad',
#   'alcohol',
#   'count',
#   'arbitrary',
#   'age',
#   'requirement',
#   'short',
#   'sighted',
#   'prohibition'],
#  ['rafael',
#   'pinto',
#   'wouldn',
#   'agree',
#   'having',
#   'avenue',
#   'income',
#   'level',
#   'cripple',
#   'operation'],
#  ['garrett',
#   'relevant',
#   'talking',
#   'reason',
#   'tobacco',
#   'priced',
#   'high',
#   'canada',
#   'see',
#   'health',
#   'hazard',
#   'completely',
#   'right',
#   'tax',
#   'hell',
#   'order',
#   'care',
#   'kind',
#   'patient',
#   'long',
#   'run',
#   'yes',
#   'hard',
#   'streed',
#   'drug',
#   'help',
#   'prescribed',
#   'lab',
#   'medicine',
#   'come',
#   'significat',
#   'risk',
#   'aswell',
#   'im',
#   'exactly',
#   'sure',
#   'canadian',
#   'health',
#   'care',
#   'work',
#   'know',
#   'risky',
#   'drug',
#   'expensive',
#   'll',
#   'form',
#   'tax'],
#  ['alonzo',
#   'salvary',
#   'alcohol',
#   'tobacco',
#   'industry',
#   'coupled',
#   'government',
#   'entity',
#   'tip',
#   'pyramid',
#   'war',
#   'drug',
#   'government'],
#  ['christopher',
#   'brown',
#   'agree',
#   'know',
#   'lot',
#   'idea',
#   'sound',
#   'good',
#   'paper',
#   'reality',
#   'human',
#   'nature',
#   'fail',
#   'hope',
#   'try',
#   'work',
#   'bug',
#   'fight',
#   'war',
#   'drug',
#   'obviously',
#   'work'],
#  ['netherlands',
#   'uruguay',
#   'contradicts',
#   'favor',
#   'know',
#   'fact',
#   'work',
#   'city',
#   'police',
#   'year',
#   'harder',
#   'drug',
#   'criminal',
#   'raised',
#   'kidnaps',
#   'robbery',
#   'assault',
#   'rifle'],
#  ['jonny',
#   'look',
#   'country',
#   'starting',
#   'relax',
#   'law',
#   'drug',
#   'think',
#   'consequence',
#   'non',
#   'registration',
#   'think',
#   'life',
#   'drug',
#   'user',
#   'cusp',
#   'abuser',
#   'think',
#   'moral',
#   'majority',
#   'far',
#   'distanced',
#   'live',
#   'hand',
#   'mouth',
#   'existence',
#   'think',
#   'attitude',
#   'hater',
#   'begrudge',
#   'kind',
#   'welfare',
#   'funding',
#   'realising',
#   'problem',
#   'naively',
#   'believe',
#   'sort',
#   'society',
#   'ill',
#   'handgun',
#   'yes',
#   'think',
#   'notice',
#   'avoided',
#   'riposte',
#   'arrogant',
#   'tone',
#   'poorly',
#   'worded',
#   'typed',
#   'comment',
#   'speaking',
#   'experience'],
#  ['ripkermit', 'world', 'look', 'small', 'big', 'blinker'],
#  ['clearly', 'educated'],
#  ['rem', 'wonder', 'll', 'change', 'ya', 'know', 'going', 'going', 'year'],
#  ['offer',
#   'education',
#   'fact',
#   'drug',
#   'safety',
#   'people',
#   'knowledgeable',
#   'effect',
#   'drug',
#   'aware',
#   'consequence',
#   'serf',
#   'incentive',
#   'use',
#   'moderation',
#   'care'],
#  ['acab'],
#  [],
#  ['titled', 'interview', 'psychopath'],
#  ['benjamin', 'sheard'],
#  ['shoguner',
#   'relish',
#   'mental',
#   'game',
#   'job',
#   'wouldnt',
#   'surprised',
#   'twice',
#   'divorced',
#   'presently',
#   'making',
#   'life',
#   'living',
#   'hell',
#   'newest',
#   'partner'],
#  ['agree', 'dude', 'fucked', 'prey', 'weak', 'empathy', 'friend', 'turning'],
#  [],
#  [],
#  ['sociopath'],
#  ['showing', 'remorse', 'guilt', 'action', 'psychopath', 'proud'],
#  ['benjamin', 'sheard', 'sure', 'understand', 'psychopath'],
#  ['white', 'cuckold'],
#  ['damn', 'job', 'sound', 'fun', 'getting', 'new', 'identity', 'dangerous'],
#  ['interesting'],
#  ['interesting'],
#  ['wow', 'open', 'honest', 'guy', 'especially', 'preyed', 'weak', 'like'],
#  ['technically',
#   'preyed',
#   'weak',
#   'access',
#   'people',
#   'hidden',
#   'preying',
#   'lot',
#   'weak',
#   'people',
#   'lot',
#   'worse',
#   'way',
#   'trying',
#   'people',
#   'preying',
#   'weak',
#   'thought',
#   'better',
#   'better',
#   'dislike',
#   'cop',
#   'calling',
#   'selfish',
#   'drug',
#   'dealer',
#   'prey',
#   'people',
#   'day',
#   'bit',
#   'far',
#   'away',
#   'reality'],
#  ['liquidminds', 'said'],
#  ['liquidminds',
#   've',
#   'seen',
#   'devastation',
#   'left',
#   'undercover',
#   'police',
#   'ops',
#   'low',
#   'level',
#   'body',
#   'literally',
#   'getting',
#   'life',
#   'ruined',
#   'helped',
#   'undercover',
#   'pig',
#   'listen',
#   'half',
#   'video',
#   'cop',
#   'admits',
#   'work',
#   'fruitless',
#   'war',
#   'drug',
#   'stand',
#   'fit',
#   'purpose',
#   'continually',
#   'punishes',
#   'weak',
#   'vulnerable',
#   'change',
#   'proposes',
#   'end',
#   'echoed',
#   'drug',
#   'treatment',
#   'service',
#   'globe',
#   'kid',
#   'current',
#   'war',
#   'drug',
#   'model',
#   'dog',
#   'remain',
#   'untouched'],
#  ['rin', 'tin', 'dont'],
#  ['yaowadeez', 'snm', 'ignorant', 'comment', 've', 'read', 'congrats'],
#  ['rin',
#   'tin',
#   'criticise',
#   'method',
#   'criticising',
#   'intention',
#   'people',
#   'claim',
#   'police',
#   'evil',
#   'want',
#   'evil',
#   'fact',
#   'want',
#   'good',
#   'happen',
#   'cause',
#   'bad',
#   'thing',
#   'discussion',
#   'pointless',
#   'people',
#   'distinguish',
#   'intention',
#   'action',
#   'rational',
#   'conversation',
#   'possible'],
#  ['liquidminds',
#   've',
#   'worked',
#   'drug',
#   'rehab',
#   'aftercare',
#   'service',
#   'close',
#   'couple',
#   'decade',
#   've',
#   'involved',
#   'number',
#   'initiative',
#   'involving',
#   'local',
#   'police',
#   'force',
#   'unfortunately',
#   'large',
#   'police',
#   'level',
#   'care',
#   'destruction',
#   'cause',
#   'ultimately',
#   'arrest',
#   'long',
#   'ultimate',
#   'arrest',
#   'record',
#   'appear',
#   'high',
#   'job',
#   'like',
#   'far',
#   'ironically',
#   'one',
#   'wanting',
#   'change',
#   'frequently',
#   'end',
#   'leaving',
#   'police',
#   'working',
#   'treatment',
#   'rehab',
#   'aftercare',
#   'sector'],
#  ['liquidminds',
#   'method',
#   'police',
#   'cruel',
#   'destructive',
#   'question',
#   'intention',
#   'police',
#   'placed',
#   'pedestal',
#   'shouldn',
#   'act',
#   'wrong',
#   'held',
#   'highest',
#   'standard',
#   'scrutiny',
#   'hold',
#   'life',
#   'hand'],
#  ['下佐粉ケイ', 'exactly'],
#  ['give', 'shit', 'weak', 'choice'],
#  ['rin',
#   'tin',
#   'job',
#   'care',
#   'job',
#   'job',
#   'disrupt',
#   'people',
#   'high',
#   'risk',
#   'situation',
#   'video',
#   'subthreads',
#   'smack',
#   'people',
#   'want',
#   'perfect',
#   'solution',
#   'fewer',
#   'dead',
#   'people',
#   'adequate',
#   'start'],
#  [],
#  ['rin',
#   'tin',
#   'obvious',
#   'answer',
#   'ignorant',
#   'eh',
#   'childish',
#   'horseshit'],
#  ['saying'],
#  ['ntl',
#   's',
#   'people',
#   'unfortunately',
#   'agree',
#   'drug',
#   'regulated',
#   'supervised',
#   'injection',
#   'site',
#   'like',
#   'europe'],
#  ['omg',
#   'million',
#   'subscriber',
#   'hope',
#   'day',
#   'gonna',
#   'million',
#   'subscriber',
#   'gonna'],
#  ['won'],
#  ['yall', 'posted'],
#  ['sir', 'add', 'subtitle'],
#  ['cover', 'onee', 'chan'],
#  ['mission', 'destroy', 'fake', 'weaboos', 'naruto', 'artifact', 'destroy'],
#  ['bate', 'em', 'poki', 'ramune', 'friend', 'em', 'month', 'go'],
#  ['meme', 'tube', 'hang', 'irl'],
#  ['vice', 'employ'],
#  ['sure', 'reference', 'medium', 'experience', 'apply', 'online'],
#  ['ll', 'employ', 'anybody'],
#  ['remotely', 'consider', 'hiring', 'reading', 'comment'],
#  ['colour', 'hate', 'white', 'men', 'gender', 'hired'],
#  ['dress',
#   'like',
#   'hipster',
#   'sjw',
#   'hashtags',
#   'new',
#   'brooklyn',
#   'office',
#   'dimwit',
#   'apparently',
#   'hire',
#   'fit',
#   'mold'],
#  ['watch',
#   'insignificant',
#   'man',
#   'vice',
#   'youtube',
#   'kejriwal',
#   'ji',
#   'pm',
#   'india'],
#  [],
#  ['went', 'insignificant', 'man', 'idiot'],
#  ['somesh', 'chal', 'feku', 'kutte'],
#  ['enzo',
#   'cittadino',
#   'enzo',
#   'read',
#   'english',
#   'said',
#   'watch',
#   'insignificant',
#   'man',
#   'movie',
#   'youtube',
#   'vice'],
#  ['gentle', 'people', 'trying', 'communicate'],
#  ['pedro',
#   'rodrigues',
#   'yes',
#   'plz',
#   'watch',
#   'insignificant',
#   'man',
#   'movie',
#   'youtube',
#   'vice'],
#  ['comment', 'confusing'],
#  ['watched', 'insignificant', 'man', 'film', 'vice', 'youtube'],
#  ['drug', 'addictz'],
#  ['vice', 'gay'],
#  ['terrarium', 'america', 'common'],
#  [],
#  ['finally', 'good', 'vice'],
#  ['enjoy', 'white', 'racist', 'guilt', 'content'],
#  ['errl', 'shmirl'],
#  ['reupload', 'different', 'title', 'different', 'editing'],
#  ['shit', 'reupload', 'retardoad'],
#  ['errl',
#   'shmirl',
#   'race',
#   'derived',
#   'guilt',
#   'law',
#   'racist',
#   'follow',
#   'colored',
#   'folk',
#   'shit'],
#  ['el', 'er', 'sb', 'nike', 'usa', 'governer'],
#  ['shut'],
#  ['interesting'],
#  ['dangerous', 'job', 'incredible', 'story', 'tell'],
#  ['story', 'payoff'],
#  ['disgusting', 'story', 'gain', 'trust', 'arrest', 'destroy', 'life'],
#  [],
#  ['michael',
#   'jay',
#   'value',
#   'investing',
#   'uk',
#   'glamorous',
#   'undercover',
#   'nick',
#   'crack',
#   'head',
#   'ask',
#   'help',
#   'buy',
#   'shit',
#   'nick'],
#  ['story', 'isn', 'job', 'drug', 'policy'],
#  ['brainwashed', 'dumbshit'],
#  ['aren', 'silence', 'equal', 'survival'],
#  ['mean', 'told', 'story'],
#  ['errl', 'shmirl', 'obviously', 'caught', 'good', 'going'],
#  [],
#  ['story', 'told', 'clever', 'way'],
#  ['life', 'experience', 'old', 'grey', 'story', 'likely', 'left'],
#  ['worse',
#   'tell',
#   'usel',
#   'es',
#   'like',
#   'having',
#   'million',
#   'dollar',
#   'ottoman',
#   'currency'],
#  ['ok'],
#  ['hey', 'bat', 'man', 'piderman'],
#  ['micheal', 'jay', 'fakerr'],
#  ['feel', 'like', 'itt', 'got', 'joke'],
#  ['glamorous', 'wish', 'vice', 'medium', 'stop', 'making', 'way'],
#  ['ftp'],
#  ['going', 'lost', 'shower', 'spread', 'butt', 'cheek', 'fart'],
#  ['lmao'],
#  ['blatantly', 'stick', 'cheeky', 'finger', 'mike'],
#  ['thought'],
#  ['liked', 'send', 'right', 'baby'],
#  ['fart', 'make', 'sense', 'gay'],
#  ['opposite', 'push', 'sound', 'intense'],
#  ['better', 'shower', 'tbh', 'thanks', 'discretion'],
#  ['comment', 'highlighted', 'know', 'secret', 'mike'],
#  ['taking',
#   'bath',
#   'bubble',
#   'soothing',
#   'stinky',
#   'kind',
#   'like',
#   'sweet',
#   'sour',
#   'effect'],
#  ['feeling',
#   'water',
#   'running',
#   'caressing',
#   'anus',
#   'pleasing',
#   'huh',
#   'lol'],
#  ['mike',
#   'buttcheeks',
#   'forth',
#   'carefully',
#   'play',
#   'bar',
#   'overture',
#   'flugel',
#   'horn',
#   'section'],
#  ['feel', 'brother'],
#  ['need', 'counseling', 'imagining'],
#  ['make', 'sound', 'like', 'angry', 'goose'],
#  ['oh', 'yes'],
#  [],
#  ['squat', 'toilet', 'seat'],
#  ['hahaha'],
#  ['plop',
#   'prefer',
#   'sit',
#   'toilet',
#   'backwards',
#   'way',
#   'handy',
#   'shelf',
#   'coloring',
#   'book',
#   'juice',
#   'box'],
#  ['feel'],
#  ['bother',
#   'commenting',
#   'shit',
#   'clearly',
#   'copied',
#   'pasted',
#   'genius',
#   'copied',
#   'pasted',
#   'people',
#   'think',
#   'dumb',
#   'boring',
#   'unfunny',
#   'shit',
#   'worth',
#   'posting'],
#  ['philip', 'doenau', 'think', 'funny', 'fart', 'bit'],
#  ['colleague',
#   'disguised',
#   'bag',
#   'cocaine',
#   'consumed',
#   'suspect',
#   'day',
#   'job',
#   'tragic'],
#  ['allsorts', 'funny', 'barstad'],
#  ['priceless', 'bro', 'ha', 'ha', 'ha', 'damn'],
#  ['ve', 'missing', 'entire', 'life'],
#  ['good'],
#  ['write', 'boosh'],
#  ['peed', 'little'],
#  ['hahaha', 'lol'],
#  ['brass', 'eye'],
#  [],
#  ['enjoyed', 'videoooo'],
#  ['amazing', 'great', 'work']]

# %%
# %%time
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=3,id2word=dictionary, passes=20,eta=2,alpha=2)
#lda_model.save('lda.model')
# Out:
# Wall time: 15.1 s

# %%
for idx, topic in lda_model.print_topics(num_words=5):
    print('Topic: {} Word: {}\n'.format(idx, topic))

# one topic shows people's opinion on this topic 
# one topic shows people;s attitude towards VICE Media
# Out:
# Topic: 0 Word: 0.026*"drug" + 0.015*"people" + 0.004*"like" + 0.004*"life" + 0.004*"war"
#
# Topic: 1 Word: 0.006*"cop" + 0.003*"think" + 0.003*"slave" + 0.003*"shit" + 0.002*"drug"
#
# Topic: 2 Word: 0.007*"vice" + 0.004*"guy" + 0.004*"like" + 0.004*"video" + 0.003*"police"

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(lda_model, bow_corpus, dictionary)
# Out:
# C:\Users\samuelmao\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.031661  0.001224       1        1  53.671253
# 1     -0.011200 -0.006889       2        1  24.082228
# 2     -0.020461  0.005665       3        1  22.246521, topic_info=     Category        Freq         Term       Total  loglift  logprob
# term
# 18    Default  129.000000         drug  129.000000  30.0000  30.0000
# 111   Default   20.000000         vice   20.000000  29.0000  29.0000
# 56    Default   79.000000       people   79.000000  28.0000  28.0000
# 14    Default   24.000000          cop   24.000000  27.0000  27.0000
# 1     Default   17.000000          guy   17.000000  26.0000  26.0000
# 10    Default   11.000000        video   11.000000  25.0000  25.0000
# 568   Default    7.000000        slave    7.000000  24.0000  24.0000
# 181   Default   11.000000       police   11.000000  23.0000  23.0000
# 159   Default   12.000000          man   12.000000  22.0000  22.0000
# 649   Default   11.000000          job   11.000000  21.0000  21.0000
# 127   Default   14.000000        think   14.000000  20.0000  20.0000
# 6     Default   12.000000         shit   12.000000  19.0000  19.0000
# 386   Default   17.000000      illegal   17.000000  18.0000  18.0000
# 31    Default    6.000000      million    6.000000  17.0000  17.0000
# 339   Default   12.000000         good   12.000000  16.0000  16.0000
# 314   Default   19.000000      problem   19.000000  15.0000  15.0000
# 869   Default    5.000000    sociopath    5.000000  14.0000  14.0000
# 40    Default   21.000000          war   21.000000  13.0000  13.0000
# 478   Default    8.000000        world    8.000000  12.0000  12.0000
# 300   Default    5.000000        watch    5.000000  11.0000  11.0000
# 7     Default    7.000000        story    7.000000  10.0000  10.0000
# 32    Default   19.000000        money   19.000000   9.0000   9.0000
# 569   Default    4.000000      slavery    4.000000   8.0000   8.0000
# 102   Default    9.000000      country    9.000000   7.0000   7.0000
# 355   Default    6.000000  interesting    6.000000   6.0000   6.0000
# 59    Default   18.000000       racism   18.000000   5.0000   5.0000
# 546   Default    4.000000     majority    4.000000   4.0000   4.0000
# 414   Default    5.000000           ex    5.000000   3.0000   3.0000
# 243   Default   21.000000          use   21.000000   2.0000   2.0000
# 3     Default   33.000000         like   33.000000   1.0000   1.0000
# ...       ...         ...          ...         ...      ...      ...
# 417    Topic3    2.106100      enjoyed    5.291225   0.5818  -6.8533
# 231    Topic3    1.359950         cool    3.441786   0.5744  -7.2907
# 829    Topic3    1.237064   propaganda    3.133556   0.5736  -7.3854
# 167    Topic3    1.355012      playing    3.450638   0.5682  -7.2943
# 186    Topic3    2.356200      fucking    6.045264   0.5608  -6.7410
# 421    Topic3    1.612872      youtube    4.140991   0.5601  -7.1201
# 117    Topic3    1.109757        rehab    2.852581   0.5589  -7.4940
# 1458   Topic3    1.101296        depth    2.832893   0.5582  -7.5016
# 2698   Topic3    0.978349    aftercare    2.525905   0.5545  -7.6200
# 237    Topic3    1.980212         weak    5.129714   0.5511  -6.9149
# 297    Topic3    1.420348      geordie    3.724307   0.5390  -7.2472
# 1210   Topic3    1.547659           ur    4.148343   0.5170  -7.1614
# 1704   Topic3    1.320113         wish    3.482246   0.5330  -7.3204
# 299    Topic3    1.530181      podcast    4.128551   0.5104  -7.1727
# 3      Topic3    7.906086         like   33.365864   0.0631  -5.5305
# 336    Topic3    2.310308          bad    7.450456   0.3321  -6.7607
# 888    Topic3    1.864503         dude    5.572939   0.4081  -6.9751
# 6      Topic3    3.191142         shit   12.710458   0.1209  -6.4377
# 265    Topic3    2.884488   undercover   11.589937   0.1122  -6.5388
# 409    Topic3    2.797650           ve   11.301351   0.1068  -6.5693
# 355    Topic3    1.931024  interesting    6.290765   0.3220  -6.9400
# 236    Topic3    2.209884         true    8.671633   0.1359  -6.8052
# 14     Topic3    2.934171          cop   24.212030  -0.6074  -6.5217
# 216    Topic3    2.437733         want   16.284742  -0.3962  -6.7070
# 36     Topic3    1.953831        right   10.733718  -0.2006  -6.9283
# 89     Topic3    1.905899         make   10.082652  -0.1629  -6.9531
# 370    Topic3    1.744231      comment    7.113391   0.0973  -7.0418
# 99     Topic3    1.852321          way   14.076849  -0.5251  -6.9817
# 56     Topic3    2.114484       people   79.039917  -2.1182  -6.8493
# 158    Topic3    1.883097         life   23.488554  -1.0206  -6.9652
#
# [172 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 482       1  0.394631  accountability
# 482       2  0.394631  accountability
# 482       3  0.394631  accountability
# 120       1  0.825178          addict
# 120       2  0.075016          addict
# 120       3  0.075016          addict
# 588       1  0.781424        addicted
# 588       2  0.130237        addicted
# 588       3  0.130237        addicted
# 375       1  0.785839       addiction
# 375       2  0.130973       addiction
# 375       3  0.130973       addiction
# 484       1  0.355481          africa
# 484       2  0.355481          africa
# 484       3  0.355481          africa
# 485       1  0.394629         african
# 485       2  0.394629         african
# 485       3  0.394629         african
# 2698      1  0.395898       aftercare
# 2698      2  0.395898       aftercare
# 2698      3  0.395898       aftercare
# 487       1  0.603952         america
# 487       2  0.301976         america
# 487       3  0.100659         america
# 490       1  0.355477            arab
# 490       2  0.355477            arab
# 490       3  0.355477            arab
# 195       1  0.262286             ask
# 195       2  0.524572             ask
# 195       3  0.262286             ask
# ...     ...       ...             ...
# 99        1  0.781425             way
# 99        2  0.071039             way
# 99        3  0.142077             way
# 237       1  0.389885            weak
# 237       2  0.194943            weak
# 237       3  0.389885            weak
# 449       1  0.828754            weed
# 449       2  0.092084            weed
# 449       3  0.092084            weed
# 584       1  0.321733            went
# 584       2  0.321733            went
# 584       3  0.321733            went
# 225       1  0.750790           white
# 225       2  0.200211           white
# 225       3  0.050053           white
# 1704      1  0.287171            wish
# 1704      2  0.287171            wish
# 1704      3  0.287171            wish
# 267       1  0.587408            work
# 267       2  0.335662            work
# 267       3  0.167831            work
# 478       1  0.451237           world
# 478       2  0.451237           world
# 478       3  0.112809           world
# 268       1  0.909287            year
# 268       2  0.075774            year
# 268       3  0.075774            year
# 421       1  0.482976         youtube
# 421       2  0.241488         youtube
# 421       3  0.482976         youtube
#
# [366 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud

wc = WordCloud(background_color="white", max_words=2000)
# generate word cloud
wc.generate(''.join(df['text']))

import matplotlib.pyplot as plt
# %matplotlib inline


# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure(figsize=(4, 3))
plt.axis("off")
plt.show()

# %% [markdown]
# ### sentiment analysis

# %%
from textblob import TextBlob


def sentiment_func(x):
    sentiment = TextBlob(x['text'])
    x['polarity'] = sentiment.polarity
    x['subjectivity'] = sentiment.subjectivity
    return x

sample = df.apply(sentiment_func, axis=1)

sample.head(10)
# Out:
#                 author                         cid  \
# 0         Jessica Anne  UgzSsKbt4sFSenKFwed4AaABAg
# 1               eric t  UgyUSy_h7yM8zWjBqYh4AaABAg
# 2               Zach R  Ugx5UKyJHBdvXmdIxK14AaABAg
# 3          Lev Myshkin  UgztLzG86StfFJi_qLZ4AaABAg
# 4               E DubZ  UgyH7-hMSf6nedCO-S54AaABAg
# 5          Ben Sorrell  UgwlgpVvzxYoQm6gpsZ4AaABAg
# 6        Eric Mitchell  Ugy9MzW_M4LAV2d4Dvl4AaABAg
# 7            J Wallace  Ugy9thu5rvpgYO3d9994AaABAg
# 8             Dan Matz  UgxHXnKx1X_vGqYu1_14AaABAg
# 9  Octavio Vega-Orozco  UgxCDBnlGnZr8pRBaSF4AaABAg
#
#                                                 text                time  \
# 0  This really seems like a guy who deserves an h...      32 minutes ago
# 1  Wow a cop that gets it! It'll never happen tho...        13 hours ago
# 2  The war on drugs is a war on people who consum...        13 hours ago
# 3  A war on drugs sounds amazing, thousands of so...        18 hours ago
# 4  The govt realizes how futile the drug war in r...        19 hours ago
# 5  socialism from the same country that allows mu...        22 hours ago
# 6  Excellent, I love VICE ... let’s legalise ever...        23 hours ago
# 7  All drugs should be decrimimalized, I dont thi...  1 day ago (edited)
# 8  I think they need to change Vice to everybody ...           1 day ago
# 9  what does "they were just taking a mickey" mean?﻿           1 day ago
#
#    polarity  subjectivity
# 0  0.166667      0.500000
# 1  0.200824      0.677747
# 2  0.000000      0.766667
# 3  0.237500      0.637500
# 4  0.015556      0.291111
# 5  0.200000      0.558333
# 6  0.750000      0.800000
# 7  0.200000      0.200000
# 8  0.000000      0.000000
# 9  0.000000      0.000000

# %%
ans=TextBlob("Excellent, I love VICE ... let’s legalise every drug and sending drug dealers and users to rehab")

# %%
#chekc how word "Vice" is being treated
print("noun phrase:",ans.noun_phrases)
print("noun tags:",ans.tags)
# Out:
# noun phrase: ['excellent', 'vice', '’ s legalise', 'drug dealers']
# noun tags: [('Excellent', 'NNP'), ('I', 'PRP'), ('love', 'VBP'), ('VICE', 'NNP'), ('let', 'VBD'), ('’', 'NNP'), ('s', 'VB'), ('legalise', 'NN'), ('every', 'DT'), ('drug', 'NN'), ('and', 'CC'), ('sending', 'VBG'), ('drug', 'NN'), ('dealers', 'NNS'), ('and', 'CC'), ('users', 'NNS'), ('to', 'TO'), ('rehab', 'VB')]

# %%
ans.subjectivity
# Out:
# 0.8

# %%
#The sentiment property returns a namedtuple of the form Sentiment(polarity, subjectivity). 
#The polarity score is a float within the range [-1.0, 1.0].  -1 is negative to the content
#The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
sample["polarity"].plot.hist()

# %%
#view comments that has a positive polarity to the contents
pd.options.display.max_rows
#pd.set_option('display.max_colwidth', -1)
sample[sample["polarity"]>0]["text"]
# Out:
# 0      This really seems like a guy who deserves an h...
# 1      Wow a cop that gets it! It'll never happen tho...
# 3      A war on drugs sounds amazing, thousands of so...
# 4      The govt realizes how futile the drug war in r...
# 5      socialism from the same country that allows mu...
# 6      Excellent, I love VICE ... let’s legalise ever...
# 7      All drugs should be decrimimalized, I dont thi...
# 11     "I just made the lives of the vulnerable more ...
# 16     He is a smart boi. Many people can’t accept wh...
# 19     its always been mainly about the money not to ...
# 23     I dress smart & to look at me you'd not likely...
# 25                         This sounds like a cool game﻿
# 26     What a truly piece of shit.  Manipulating the ...
# 30                     What did he say at the very end?﻿
# 34     Want a better insight into this mans life, go ...
# 38     This isn't true I'm just making a joke .....bu...
# 40     His book is the best book I have ever read. Go...
# 44                                          Great work.﻿
# 47     What a legend. Has enough balls to pull off un...
# 48     this makes me laugh because i live in Derby :'...
# 50                                      MORE PLEASE !!!﻿
# 51     One day someone will see this comment and he'l...
# 53     Did this guy just say..that to get rid of the ...
# 54     Yup most of the time it feels like the cops ar...
# 57     Is vice back? the channel is shit now and zero...
# 59                                        He a real one﻿
# 62     Like that System of a Down song said: "All res...
# 64     Vulnerable people do not act on morals, they a...
# 66     Seeing the comments from Americans talking shi...
# 67     It is true. Our own governments bring that shi...
#                              ...
# 742    He is showing remorse and guilt for his action...
# 745    Damn this job sounds fun getting to make a new...
# 748    Wow very open and honest guy especially how he...
# 750                         @liquidminds Very well said﻿
# 753    @yaowadeez snm One of the most ignorant commen...
# 755    @liquidminds I've worked in drug rehab and aft...
# 759    @Rin Tin \nIt's not their job to care, that's ...
# 761    Rin Tin The most obvious answer is the most "i...
# 773    Sure do you have references,media experience, ...
# 783       Be gentle, people. It's trying to communicate﻿
# 791                   Finally something good again vice﻿
# 792       U don't enjoy the white racist guilt content?﻿
# 799                                 Interesting indeed.﻿
# 800    Dangerous job, but if you make it out, you wil...
# 807    Even when you're out, you aren't REALLY out......
# 809    Errl Shmirl- You were obviously caught by one ...
# 811           those stories can be told in clever ways.﻿
# 812    life is all about experiences.  When you're ol...
# 824        Liked this to send it right to the top baby!﻿
# 826    Opposite for me. I push them together so that ...
# 827    This seems better than doing it not in the sho...
# 829    I do it while taking a bath, the bubbles are s...
# 839    @Plop I prefer to sit on my toilet backwards, ...
# 842    Philip Doenau I think they find it funny becau...
# 844                          M Allsorts u funny barstad﻿
# 845                        priceless bro ha ha ha damn.﻿
# 847                                           Good that﻿
# 850                                         Hahaha lol.﻿
# 853                               Enjoyed this videoooo﻿
# 854                        That's amazing great work ^^﻿
# Name: text, Length: 307, dtype: object

# %%
### divide with vice and without vice
#do a sentiment analysis with VICE!

# %%
txt=df["text"].str.lower()

# %%
#find the location and create a list where comments mentioned VICE
lst_with_vice=[]
for i,j in enumerate(txt):
    res=re.findall("vice", j)
    if len(res)!=0:
        lst_with_vice.append(i)
lst_with_vice
# Out:
# [5,
#  6,
#  8,
#  17,
#  35,
#  37,
#  43,
#  57,
#  73,
#  89,
#  90,
#  96,
#  103,
#  107,
#  129,
#  141,
#  142,
#  147,
#  156,
#  166,
#  171,
#  179,
#  182,
#  202,
#  207,
#  212,
#  229,
#  233,
#  236,
#  237,
#  245,
#  247,
#  255,
#  325,
#  326,
#  328,
#  401,
#  418,
#  424,
#  431,
#  435,
#  440,
#  487,
#  548,
#  567,
#  575,
#  599,
#  615,
#  617,
#  618,
#  624,
#  673,
#  686,
#  751,
#  755,
#  772,
#  778,
#  782,
#  784,
#  786,
#  788,
#  791,
#  818]

# %%
#all_comments_about_vice=[df.iloc[x] for x in lst_with_vice]
#all_comments_about_vice

# %%
vice_df=df.iloc[lst_with_vice]

# %%
from textblob import TextBlob


def sentiment_func_vice(x):
    sentiment = TextBlob(x["text"])
    x['polarity'] = sentiment.polarity
    x['subjectivity'] = sentiment.subjectivity
    return x


about_vice = vice_df.apply(sentiment_func_vice, axis=1)
# about_vice["polarity"].plot.hist()

# %%
about_vice["polarity"].plot.hist()

# %%
about_vice
# Out:
#                     author                                                cid  \
# 5              Ben Sorrell                         UgwlgpVvzxYoQm6gpsZ4AaABAg
# 6            Eric Mitchell                         Ugy9MzW_M4LAV2d4Dvl4AaABAg
# 8                 Dan Matz                         UgxHXnKx1X_vGqYu1_14AaABAg
# 17              first last                         UgyO6eWTDayAvmnnmph4AaABAg
# 35     CanadianImperialist                         UgyueCSV5_Ru9e8es6F4AaABAg
# 37         YellowTissueBox                         UgwYSiNicMqULPL52ZB4AaABAg
# 43          AudibleVisible                         Ugx6rdnQtZBDazh3maZ4AaABAg
# 57          naz salabarria                         Ugy5aXHBDA0IRjWCRyN4AaABAg
# 73          Admiral Ackbar                         UgzGHehxQMd7gySQLER4AaABAg
# 89             minusmodest                         Ugx6yzSKbL0z-dTXTdN4AaABAg
# 90                   Brady                         Ugw6mFGbhE-5iAXtEGJ4AaABAg
# 96          Rudy x Mitchel                         UgwWin_Ng6367DCj_k94AaABAg
# 103             Kyle Hills                         UgxPsMNggwVwueqDnVF4AaABAg
# 107         Hidden History                         UgwpJCKNPDcyVrpkizN4AaABAg
# 129         BLUECOLLARJOHN                         UgwNTpIDR2ZDe8QBtoJ4AaABAg
# 141              after1001                         Ugydat6WKEB9xPWrnAN4AaABAg
# 142  Adrijus Remeškevičius                         Ugyh35F-TQ2VMmjiLSl4AaABAg
# 147          PickleishBILL                         Ugx6G9eVKQ7-BGdQ5CZ4AaABAg
# 156             Sp0okykidd                         UgxLBO4dUlUbKrcbANJ4AaABAg
# 166         the resistance                         UgwWcYI26TNJ8QGOwTx4AaABAg
# 171                 klmfao                         UgyVSEySmkB9Ee5p0AN4AaABAg
# 179          Kristian Todt                         UgyrvHptPegkOq-raEh4AaABAg
# 182         ChumpyChicken2                         UgwBdVoYqjSCk7Rg3PF4AaABAg
# 202        Cartoons My Man                         UgyEWDOh5DVnbjdNIRN4AaABAg
# 207                  suroj                         Ugyz4T43p3BoZ-ixnYx4AaABAg
# 212               MOON MAN                         UgxnDU4P9zJn-T7lHZd4AaABAg
# 229             therant311                         Ugz9X1Zjxf6DgwIy_2R4AaABAg
# 233                Okie TC                         UgyfbUCH1gOQZxJNjq14AaABAg
# 236              jason4275                         UgwqJr_CmE9-KcRskw54AaABAg
# 237      Devils Right Hand                         UgzGZrdae5TEU8aw-Rl4AaABAg
# ..                     ...                                                ...
# 325        stripymccatpuss                         UgztZQJtVrN8Tqby2jp4AaABAg
# 326                Flivver                         Ugy6loU-TYgPxn-TNGR4AaABAg
# 328               COLT Fin                         UgwnO2wGIYODZCqX5Rh4AaABAg
# 401                 Fintan                         UgyVccTGXDe0yRXKzbV4AaABAg
# 418              malayneum                         UgzHkyoRGK3UF5dtDRB4AaABAg
# 424             KACU LASHA                         Ugy52rlrikB5eKlPRah4AaABAg
# 431              Shikam187  Ugy52rlrikB5eKlPRah4AaABAg.8lYVRfAOZdg8la185ciL14
# 435           derty QWERTY  Ugy52rlrikB5eKlPRah4AaABAg.8lYVRfAOZdg8ljwq3bfvbd
# 440           KingSteezRIP                         Ugwshk7HASDYm3rtjbV4AaABAg
# 487    Sovereign Sentience                         Ugyil0ya1L56APyPQ9x4AaABAg
# 548           Waynimations                         Ugx2uBPbZHXuftNi-Lx4AaABAg
# 567             Mad Hadder                         Ugy57y4qwvguOzsMQZ54AaABAg
# 575                   Rick                         UgzYAEe7_ESxRHP3m8N4AaABAg
# 599              Peter Pan                         UgwUCK3cVwXrKyh561Z4AaABAg
# 615      tragoedia veritas                         Ugyol3lXA59DdOSN-hh4AaABAg
# 617               packerpf  Ugyol3lXA59DdOSN-hh4AaABAg.8lYJxHc-xHV8lYl0DcbmBk
# 618             HgihAsFcuk  Ugyol3lXA59DdOSN-hh4AaABAg.8lYJxHc-xHV8lYpDe56eLY
# 624                Dan. W.  Ugyol3lXA59DdOSN-hh4AaABAg.8lYJxHc-xHV8ll5rDx97Gy
# 673            Kevin Gomez  Ugxmjf6W597R3iayHW54AaABAg.8lYJ4G0AfSE8lZ3QcXOIIH
# 686         needahaircut93                         Ugwq6H34i4LN31kB19V4AaABAg
# 751                Rin Tin  Ugy8ed9NKqdzOpmZy7R4AaABAg.8lYI6YtV5sM8lYNpkQcjw2
# 755                Rin Tin  Ugy8ed9NKqdzOpmZy7R4AaABAg.8lYI6YtV5sM8lYRv2G1lFq
# 772              Omni Enki                         UgzF5XhOyGI7j7uHEuF4AaABAg
# 778                    A K                         Ugzb5s4jv1CzTQcgL2l4AaABAg
# 782                    A K  Ugzb5s4jv1CzTQcgL2l4AaABAg.8lYHoIu3ewy8lYJNSVr_kJ
# 784                    A K  Ugzb5s4jv1CzTQcgL2l4AaABAg.8lYHoIu3ewy8lYK2MZ6ckf
# 786                    A K                         UgwyjLcC-lBDvyQ2vJB4AaABAg
# 788      Terrarium America                         UgzlyTniAccOaz1FToF4AaABAg
# 791     Superhuman Fitness                         UgylpMNKl2uHYuo3L2x4AaABAg
# 818                No Name  UgwmlmW_DBdV6zqMSAt4AaABAg.8lYHaI5Y7rZ8llidGrUYbZ
#
#                                                   text                 time  \
# 5    socialism from the same country that allows mu...         22 hours ago
# 6    Excellent, I love VICE ... let’s legalise ever...         23 hours ago
# 8    I think they need to change Vice to everybody ...            1 day ago
# 17   So imagine meth was legal and regulated would,...           2 days ago
# 35   Its all racist [citation needed] its vice tho....           3 days ago
# 37   Vice is a cancerous fucking mole on the news l...           3 days ago
# 43                                 Yo vice is back 👍👍﻿           3 days ago
# 57   Is vice back? the channel is shit now and zero...           4 days ago
# 73   Scrolls down. Sees channel: VICE. Flags and le...           4 days ago
# 89                                       this is vice﻿           5 days ago
# 90   Excellent piece @vice but this ish is strictly...  5 days ago (edited)
# 96   lol he isn't even a US cop how does this have ...           5 days ago
# 103  Watch it VICE, you're still a really good but ...           5 days ago
# 107  Why is Vice always pushing racism bs and propa...           5 days ago
# 129  Of course vice pushing the racist narrative ag...           5 days ago
# 141  Finally vice is telling the TRUTH again. They ...           5 days ago
# 142                        Vice, isn't this reloaded?﻿           5 days ago
# 147        Wouldn’t be vice without some race card bs﻿           5 days ago
# 156  Umm the UK has mexicans?\n\nIt's sad to see vi...           5 days ago
# 166  DRUGS DRUGS DRUGS vice is a pack of Meth heads..﻿           5 days ago
# 171   Is vice finally starting to become good again??﻿           5 days ago
# 179  Everyone is saying "for once Vice makes a good...           5 days ago
# 182  Alway been about Racism? What a virtue signall...  5 days ago (edited)
# 202  Vice, Vox, Crocks, I don't see difference I ju...           5 days ago
# 207  Nice.. more of this kind of thing please vice....           5 days ago
# 212                   Good job vice. Very interesting﻿           5 days ago
# 229  Damn, VICE is really tryna be what it used to ...           6 days ago
# 233  Vice do you think you could do a documentary a...           6 days ago
# 236                            A good video from vice﻿           6 days ago
# 237  Weird how Vice disabled the comments to anothe...           6 days ago
# ..                                                 ...                  ...
# 325  This guy likes to manipulate people....Vice, y...           6 days ago
# 326  i like how vice starts the video with some cla...           6 days ago
# 328  I'm surprised VICE has turned into a narcotic ...           6 days ago
# 401  Glad to see VICE have someone from LEAP featur...           6 days ago
# 418  what a liberal propanda. vice you should stay ...           6 days ago
# 424                  why vice is always about RACISM?﻿           6 days ago
# 431  KACU LASHA 1) racism is very prevalent 2) Vice...           5 days ago
# 435  Vice apparently doesnt know how to study drug ...            1 day ago
# 440  Come on vice let the man say the truth. Drug l...           6 days ago
# 487                          Respect .  thanks Vice .﻿           6 days ago
# 548  It’s rare but vice can still whip out good vid...           6 days ago
# 567  thank god the inmates and ex-cons don't have i...           6 days ago
# 575  Cool. It’s that doc that vice posted a shit lo...           6 days ago
# 599                 First decent vice post in a while﻿           6 days ago
# 615                  This is the vice I signed up for﻿           6 days ago
# 617  vice that takes a story someone else already d...           6 days ago
# 618             it's a re-upload dude shit's old vice﻿           6 days ago
# 624  Seriously! New Vice is almost always absolutel...            1 day ago
# 673  They cut him off before he could finish his an...           6 days ago
# 686  This is the exact same as the lad bible vid ab...           6 days ago
# 751  @liquidminds I've seen the devastation left be...           6 days ago
# 755  @liquidminds I've worked in drug rehab and aft...           6 days ago
# 772                                  VICE, employ me.﻿           6 days ago
# 778  Must watch An Insignificant man by vice on You...           6 days ago
# 782  @Enzo Cittadino Enzo can u read english ,I sai...           6 days ago
# 784  @Pedro Rodrigues yes plz watch An Insignifican...           6 days ago
# 786  Who watched""" An Insignificant man"""" film b...           6 days ago
# 788                                       Vice is gay﻿           6 days ago
# 791                 Finally something good again vice﻿           6 days ago
# 818  It's not glamorous. I wish vice and media woul...         20 hours ago
#
#      polarity  subjectivity
# 5    0.200000      0.558333
# 6    0.750000      0.800000
# 8    0.000000      0.000000
# 17   0.000000      0.500000
# 35   0.000000      0.000000
# 37  -0.125000      0.775000
# 43   0.000000      0.000000
# 57   0.075000      0.375000
# 73  -0.155556      0.288889
# 89   0.000000      0.000000
# 90   0.050150      0.480255
# 96   0.800000      0.700000
# 103  0.266667      0.533333
# 107  0.125000      0.375000
# 129  0.000000      0.000000
# 141 -0.050000      0.550000
# 142  0.000000      0.000000
# 147  0.000000      0.000000
# 156 -0.500000      1.000000
# 166  0.000000      0.000000
# 171  0.350000      0.350000
# 179  0.175000      0.600000
# 182  0.000000      0.000000
# 202  0.000000      0.000000
# 207  0.362500      0.725000
# 212  0.450000      0.450000
# 229  0.200000      0.200000
# 233  0.000000      0.000000
# 236  0.700000      0.600000
# 237 -0.350000      0.650000
# ..        ...           ...
# 325  0.200000      0.400000
# 326  0.166667      0.166667
# 328  0.116667      0.383333
# 401  0.500000      1.000000
# 418  0.000000      0.100000
# 424  0.000000      0.000000
# 431  0.188889      0.277778
# 435  0.070000      0.463333
# 440  0.102500      0.645000
# 487  0.200000      0.200000
# 548  0.500000      0.750000
# 567  0.000000      0.000000
# 575  0.033333      0.616667
# 599  0.208333      0.500000
# 615  0.000000      0.000000
# 617  0.500000      0.500000
# 618 -0.050000      0.500000
# 624 -0.102727      0.680909
# 673  0.250000      0.820000
# 686  0.125000      0.187500
# 751 -0.103788      0.337879
# 755  0.010357      0.489048
# 772  0.000000      0.000000
# 778  0.000000      0.000000
# 782  0.000000      0.000000
# 784  0.000000      0.000000
# 786  0.000000      0.000000
# 788  0.000000      0.000000
# 791  0.350000      0.800000
# 818  0.000000      0.000000
#
# [63 rows x 6 columns]
